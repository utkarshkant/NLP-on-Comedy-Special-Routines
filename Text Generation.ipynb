# %% [markdown]
# # Text Generation
#
# ## Introduction
# - Here we use Markov chains to create a basic text generation program.
# - The basic assumption of a Markov chain is that the next word is only dependent on the previous word.
#
# ## Objective
# - We are going to generate text in the style of Ali Wong, the comedian.

# %%
# read the corpus 
import pandas as pd

data = pd.read_pickle('clean_corpus_with_full_names.pkl')
data
# Out:
#                                                 transcript         full_name
# ali      ladies and gentlemen please welcome to the sta...          Ali Wong
# anthony  thank you thank you thank you san francisco th...  Anthony Jeselnik
# bill      all right thank you thank you very much thank...         Bill Burr
# bo       bo what old macdonald had a farm e i e i o and...        Bo Burnham
# dave     this is dave he tells dirty jokes for a living...    Dave Chappelle
# hasan      what’s up davis what’s up i’m home i had to ...      Hasan Minhaj
# jim         ladies and gentlemen please welcome to the ...     Jim Jefferies
# joe         ladies and gentlemen welcome joe rogan  wha...         Joe Rogan
# john     armed with boyish charm and a sharp wit the fo...      John Mulaney
# louis    introfade the music out let’s roll hold there ...        Louis C.K.
# mike     wow hey thank you thanks thank you guys hey se...    Mike Birbiglia
# ricky    hello hello how you doing great thank you wow ...     Ricky Gervais

# %%
# extract Ali Wong's transcript
ali_text = data['transcript'][0]
ali_text
# Out:
# 'ladies and gentlemen please welcome to the stage ali wong hi hello welcome thank you thank you for coming hello hello we are gonna have to get this shit over with ’cause i have to pee in like ten minutes but thank you everybody so much for coming um… it’s a very exciting day for me it’s been a very exciting year for me i turned  this year yes thank you five people i appreciate that uh i can tell that i’m getting older because now when i see an  girl my automatic thought… is “fuck you” “fuck you i don’t even know you but fuck you” ‘cause i’m straight up jealous i’m jealous first and foremost of their metabolism because  girls they could just eat like shit and then they take a shit and have a sixpack right they got thatthat beautiful inner thigh clearance where they put their feet together and there’s that huge gap here with the light of potential just radiating throughand then when they go to sleep they just go to sleep right they don’t have insomnia yet they don’t know what it’s like to have to take a ambien or download a meditation oasis podcast to calm the chatter of regret and resentment towards your family just cluttering your mind they have their whole lives ahead of them they don’t have hpv yet they just go to sleep in peace at night everybody has hpv ok everybody has it it’s ok come out already everybody has it if you don’t have it yet you go and get it you go and get it it’s coming you don’t have hpv yet you’re a fucking loser all right that’s what that says about you a lot of men don’t know that they have hpv because it’s undetectable in men it’s really fucked up hpv is a ghost that lives inside men’s bodies and says “boo” in women’s bodies my doctor told me that i have one of two strains of hpv either i have the kind that’s gonna turn into cervical cancer… …or i have the kind where my body will heal itself very helpful this doctor right so basically either i’m gonna die… or you’re in the presence of wolverine bitches we’ll find out um i can also tell that i’m getting older because my kindle is turning into a selfhelp library i’m not interested in books like fifty shades of grey ok i’m interested in the lifechanging magic of tidying up yes yes that’s right how to declutter my home to achieve inner peace and my optimum level of success that’s what your  is all about how can i turn this shit around i’m a horrible person i’m not happy with where i am how can i turn this shit around help me tony robbins help mei have a hoarding problem which i’m hoping is the center of all of my other problems i’m hoping that if the hoarding goes away the hpv will also disappear i have a hoarding problem because my mom is from a third world country and she taught me that you can never throw away anything because you never know when a dictator’s gonna overtake the country and snatch all your wealth so you better hold onto that retainer from the third grade ’cause it might come in handy as a shovel when you’re busy stuffing gold up your butt and running away from the communiststhe last time i was at home in san francisco i was trying to help her get rid of shit don’t ever do that with your mom it was like the worst experience of my life it was so emotional we were screaming and fighting and yelling and it all came to a climax when she refused to let go of a texas instruments … manual the manual she don’t even know… where the calculator is those of you under  probably don’t know what that calculator is it was this calculator that bamboozled my generation we were all required to buy it when we were in eight grade it cost like  and everybody thought it was like this judy jetson’s laptop from the future all because what it could graph it was like the tesla of my time and my mom got so emotional about the manual and she was like “you never know when you might need this” and i was like “but… i do know… that i’m gonna have to clean all this shit up when you die” “and i’m not trying to be a procrastinator anymore because according to deepakoprah t ...

# %% [markdown]
# # Build a Markov Chain
# Build a simple markov chain that creates a dictionary of the following key and value pairs.
# - The keys should be all the words in the corpus
# - The values should be a list of the words that follow the keys

# %%
# UDF to create markov chain
from collections import defaultdict

# The input is a string of text and the output will be a dictionary with each word as a key and each value as the list of words that come after the key in the text.
def markov_chain(text):
    words = text.split(' ')  # tokenize the corpus by word
    m_dict = defaultdict(list)  # initialize a default dictionary to hold all of the words and next word
    # Create a zipped list of all of the word pairs and put them in word: list of next words format
    for current_word, next_word in zip(words[0:-1], words[1:]):
        m_dict[current_word].append(next_word)
    m_dict = dict(m_dict)  # convert default dict into dictionary  
    return m_dict

# %%
# create a dictionary for Ali's comedy routine
ali_dict = markov_chain(ali_text)
ali_dict
# Out:
# {'ladies': ['and', 'go', 'who', 'they', 'and', 'who'],
#  'and': ['gentlemen',
#   'foremost',
#   'then',
#   'have',
#   'there’s',
#   'resentment',
#   'get',
#   'get',
#   'says',
#   'my',
#   'she',
#   'snatch',
#   'running',
#   'fighting',
#   'yelling',
#   'it',
#   'everybody',
#   'my',
#   'she',
#   'i',
#   'uh',
#   'i',
#   'i',
#   'the',
#   'i',
#   'i',
#   'i',
#   'we',
#   'we–',
#   'then',
#   'i',
#   'watched',
#   'i',
#   'have',
#   'that',
#   'you',
#   'recycling',
#   'disturbing',
#   'it’s',
#   'all',
#   'just…',
#   'then',
#   'be',
#   'halfvietnamese',
#   'we',
#   'his',
#   'i',
#   'slide',
#   'your',
#   'inflamed',
#   'you’re',
#   'then',
#   'i',
#   'halfjapanese',
#   'i’m',
#   'halfvietnamese',
#   'playing',
#   'rugby',
#   'on',
#   'foremost',
#   'a',
#   'the',
#   'emotionally',
#   'i',
#   '',
#   'so',
#   'neither',
#   'i',
#   'i–',
#   'then',
#   'it’s',
#   'find',
#   'start',
#   'just',
#   'caves',
#   'gets',
#   'is',
#   'then',
#   'look',
#   'like',
#   'very',
#   'for',
#   'i',
#   'she',
#   'rise',
#   'her',
#   'be',
#   'eat',
#   'watch',
#   'then',
#   'be',
#   'now',
#   'they’re',
#   'most',
#   'they’ll',
#   'in',
#   'then',
#   'digitally',
#   'then',
#   'you',
#   'you’re',
#   'then',
#   'then',
#   'then',
#   'then',
#   'steady',
#   'brings',
#   'let',
#   'reverberate',
#   'say',
#   'my',
#   'he',
#   'when',
#   'i’m',
#   'just',
#   'i',
#   'what',
#   'sicker',
#   'sicker',
#   'sicker',
#   'sicker',
#   'posted',
#   'they’re',
#   'that’s',
#   'lies',
#   'as',
#   'treat',
#   'you’ll',
#   'succeed',
#   'they',
#   'i',
#   'you',
#   'it’s',
#   'then',
#   'that’s',
#   'be',
#   'i’m',
#   'i',
#   'just',
#   'sisters',
#   'a',
#   'unusual',
#   'they’ll',
#   'boring”',
#   'all',
#   'their',
#   'wearing',
#   'famous',
#   'they',
#   'you’re',
#   'just',
#   'therefore',
#   'you',
#   'ignore',
#   'then',
#   'she',
#   'when',
#   'the',
#   'biggie',
#   'it–',
#   'it',
#   'your',
#   'there',
#   'i',
#   'a',
#   'i',
#   'push',
#   'then',
#   'then',
#   'melt',
#   'i',
#   'then',
#   'then',
#   'sniff',
#   'i',
#   'you’ve',
#   'i',
#   'outside',
#   'as',
#   'rapey',
#   'they',
#   'um…',
#   'most',
#   'see',
#   'i’d',
#   'i',
#   'he',
#   'instead',
#   'then',
#   'then',
#   'remember',
#   'then',
#   'hold',
#   'i',
#   'do',
#   'then',
#   'to',
#   'a',
#   'a',
#   'terrible',
#   'i',
#   'when',
#   'everything',
#   'the',
#   'i',
#   'then',
#   'i',
#   'most',
#   'i',
#   'he',
#   'i',
#   'held',
#   'got',
#   'i',
#   'your',
#   'just',
#   'he',
#   'i',
#   'it',
#   'leaves',
#   'dark',
#   'then',
#   'naked',
#   'a',
#   'i',
#   'i',
#   'my',
#   'then',
#   'then',
#   'recently',
#   'uh',
#   'me',
#   'now',
#   'a'],
#  'gentlemen': ['please'],
#  'please': ['welcome', 'no', 'look'],
#  'welcome': ['to', 'thank'],
#  'to': ['the',
#   'get',
#   'pee',
#   'sleep',
#   'sleep',
#   'have',
#   'take',
#   'calm',
#   'sleep',
#   'declutter',
#   'achieve',
#   'help',
#   'a',
#   'let',
#   'buy',
#   'clean',
#   'be',
#   'deepakoprah',
#   'achieve',
#   'a',
#   'trap',
#   'date',
#   'any',
#   'cool',
#   'be',
#   'go',
#   'say',
#   'a',
#   'be',
#   'do',
#   'private',
#   'this',
#   'see',
#   'leave',
#   'private',
#   'backpack',
#   'do',
#   'shut',
#   'go',
#   'be',
#   'do',
#   'incept',
#   'leave',
#   'go',
#   'my',
#   'send',
#   'him',
#   'be',
#   'sit',
#   'the',
#   'lie',
#   'women',
#   'be',
#   'continue',
#   'do',
#   'have',
#   'show',
#   'work',
#   'earn',
#   'shit',
#   'seat',
#   'eat',
#   'pull',
#   'ration',
#   'try',
#   'make',
#   'moisten',
#   'come',
#   'start',
#   'you',
#   'make',
#   'just',
#   'the',
#   'podcasts',
#   'me',
#   'come',
#   'me',
#   'get',
#   'work',
#   'eat',
#   'tell',
#   'get',
#   'you',
#   'make',
#   'fuck',
#   'marry',
#   'turn',
#   'youi',
#   'put',
#   'do',
#   'because',
#   'help',
#   'show',
#   'spank',
#   'abuse',
#   'be',
#   'be',
#   'do',
#   'her',
#   'use',
#   'say',
#   'like',
#   'get',
#   'like',
#   'the',
#   'take',
#   'see',
#   'think',
#   'heal',
#   'me',
#   'me',
#   'live',
#   'die',
#   'hide',
#   'alert',
#   'have',
#   'keep',
#   'go',
#   'be',
#   'support',
#   'be',
#   'the',
#   'protect',
#   'see',
#   'have',
#   'show',
#   'be',
#   'get',
#   'get',
#   'take',
#   'act',
#   'find',
#   'discretely',
#   'immediately',
#   'be',
#   'smell',
#   'protect',
#   'see',
#   'have',
#   'get',
#   'save',
#   'be',
#   'close',
#   'shut',
#   'see',
#   'finish',
#   'finish',
#   'come',
#   'make',
#   'be',
#   'be…',
#   'be',
#   'me',
#   'do',
#   'do',
#   'see',
#   'hire',
#   'keyser',
#   'freak',
#   'freak',
#   'it”',
#   'cleanse',
#   'assist',
#   'make',
#   'do',
#   'be',
#   'be',
#   'all',
#   'all',
#   'go',
#   'those',
#   'see',
#   'chip',
#   'keep',
#   'get',
#   'protect',
#   'trap',
#   'propose',
#   'me',
#   'harvard'],
#  'the': ['stage',
#   'light',
#   'chatter',
#   'kind',
#   'kind',
#   'presence',
#   'lifechanging',
#   'center',
#   'hoarding',
#   'hpv',
#   'country',
#   'third',
#   'communiststhe',
#   'worst',
#   'manual',
#   'calculator',
#   'future',
#   'tesla',
#   'manual',
#   'way',
#   'lucky',
#   'outside',
#   'inside',
#   'first',
#   'time',
#   'fifth',
#   'next',
#   'back',
#   'park”',
#   'middle',
#   'money',
#   'colonizer”',
#   'advantage',
#   'time',
#   'sexiest',
#   'sexiest',
#   'neck',
#   'last',
#   'rug',
#   'umami',
#   'difference',
#   'fancy',
#   'chinese',
#   'japanese',
#   'east',
#   'west',
#   'name',
#   'bathroom',
#   'bathroom',
#   'corner',
#   'wait',
#   'wall…',
#   'fuck',
#   'house',
#   'idea',
#   'man’s',
#   'message',
#   'whole',
#   'shit',
#   'fuck',
#   'woman',
#   'exact',
#   'following',
#   'goodness',
#   'coo',
#   'table',
#   'top',
#   'fuck',
#   'worst',
#   'smart',
#   'next',
#   'secret”',
#   'phrase',
#   'street',
#   'boat',
#   'best',
#   'desert',
#   'stall',
#   'end',
#   'day',
#   'goonies',
#   'velocity',
#   'butt',
#   'doo',
#   'toilet',
#   'ends',
#   'toilet',
#   'toilet',
#   'other',
#   'nerve',
#   'same',
#   'rest',
#   'promise',
#   'images',
#   'internet',
#   'back',
#   'internet',
#   'jewish',
#   'universe',
#   'pain”',
#   'pain',
#   'pain',
#   'dick',
#   'butt',
#   'tushtush',
#   'man',
#   'look',
#   'man’s',
#   'first',
#   'woman',
#   'lord',
#   'rim',
#   'most',
#   'most',
#   'woman',
#   'time',
#   'boss',
#   'boss',
#   'time',
#   'bedroom',
#   'boss',
#   'real',
#   'word',
#   'word',
#   'right',
#   'point',
#   'kind',
#   'case',
#   'audience',
#   'mom',
#   'fucking',
#   'baby’s',
#   'dream”',
#   'point',
#   'ultimate',
#   'world',
#   'rest',
#   'galapagos',
#   'phrase',
#   'women',
#   'side',
#   'hood',
#   'movie',
#   'park',
#   'sun',
#   'sun',
#   'tupac',
#   'time',
#   'time',
#   'peace',
#   'boat',
#   'pill',
#   'progesterone',
#   'conference',
#   'urge',
#   'hood',
#   'eggs',
#   'month',
#   'kraken”',
#   'time',
#   'smiley',
#   'ovulation',
#   'time',
#   'image',
#   'back',
#   'expression',
#   'fuck',
#   'indication',
#   'eye',
#   'shit',
#   'doctor',
#   'size',
#   'twins',
#   'toilet',
#   'whole',
#   'fuck',
#   'marriage',
#   'pain',
#   'table”',
#   'labor',
#   'floor',
#   'love',
#   'real',
#   'baby',
#   'house',
#   'dishes”',
#   'plants”',
#   'channel”',
#   'star',
#   'show',
#   'camera',
#   'hero',
#   'baby',
#   'baby',
#   'kind',
#   'baby',
#   'same',
#   'escrow',
#   'one',
#   'epicenter'],
#  'stage': ['ali', 'a'],
#  'ali': ['wong', 'you', 'we', 'wong'],
#  'wong': ['hi', 'have'],
#  'hi': ['hello'],
#  'hello': ['welcome', 'hello', 'we'],
#  'thank': ['you', 'you', 'you', 'you', 'you'],
#  'you': ['thank',
#   'for',
#   'everybody',
#   'five',
#   'i',
#   'but',
#   'don’t',
#   'go',
#   'go',
#   'don’t',
#   'a',
#   'can',
#   'never',
#   'better',
#   'under',
#   'might',
#   'die”',
#   'wanna',
#   'wanna',
#   'gotta',
#   'homeless',
#   'a',
#   'drop',
#   'know',
#   'go',
#   'know',
#   'feel',
#   'feel',
#   'know',
#   'feel',
#   'know',
#   'about',
#   'to',
#   'know',
#   'right',
#   'knowbut',
#   'get',
#   'get',
#   'like',
#   'don’t',
#   'knowmy',
#   'guys',
#   'know',
#   'mess',
#   'guys',
#   'know',
#   'can',
#   'can',
#   'eat',
#   'queef',
#   'know',
#   'gotta',
#   'know',
#   'marry',
#   'something',
#   'would',
#   'don’t',
#   'know',
#   'know',
#   'have',
#   'could',
#   'can',
#   'always',
#   'hurry',
#   'never',
#   'dare',
#   'know',
#   'deep',
#   'don’t',
#   'not',
#   'guys',
#   'guys',
#   'wanna',
#   'guys',
#   'telling',
#   'tell',
#   'son',
#   'start',
#   'crave',
#   'realize',
#   'know…',
#   'ain’t',
#   'now',
#   'have',
#   'gotta',
#   'gotta',
#   'don’t',
#   'gotta',
#   'put',
#   'know',
#   'haven’t',
#   'only',
#   'know',
#   'stick',
#   'know',
#   'just',
#   'as',
#   'know',
#   'ok',
#   'all',
#   'know',
#   'right”',
#   'respect',
#   'need',
#   'know',
#   'know',
#   'what',
#   'be',
#   'so',
#   'know',
#   'know',
#   'know',
#   'guys',
#   'there’s–',
#   'know',
#   'gonna',
#   'just',
#   'knowanother',
#   'gonna',
#   'just',
#   'want',
#   'know',
#   'know',
#   'remember',
#   'were',
#   'just',
#   'could',
#   'throw',
#   'could',
#   'i',
#   'ghostbusters”',
#   'scratch',
#   'can',
#   'urgently',
#   '’cause',
#   'gotta',
#   'need',
#   'guys',
#   'do',
#   'pee',
#   'when',
#   'when',
#   'to',
#   'know',
#   'that–',
#   'know',
#   'know',
#   'know',
#   'push',
#   'push',
#   'push',
#   'just',
#   'think',
#   'boom',
#   'wash',
#   'water',
#   'makin’',
#   'change',
#   'know',
#   'about',
#   'get',
#   'know',
#   'know',
#   'you',
#   'owe',
#   'see',
#   'know',
#   'know',
#   'think'],
#  'for': ['coming',
#   'coming',
#   'me',
#   'me',
#   'me',
#   'my',
#   'fashion',
#   'warmth',
#   'marriage',
#   'them',
#   'the',
#   'a',
#   'the',
#   'four',
#   'five',
#   'five',
#   'the',
#   'us',
#   'fresh',
#   'but',
#   'me',
#   'them',
#   'his',
#   'the',
#   'once',
#   'the',
#   'that’s',
#   'all',
#   'the',
#   'me',
#   'me',
#   'me',
#   'a',
#   'them',
#   'granted',
#   'a',
#   'a',
#   'me',
#   'a',
#   '',
#   '',
#   'coming',
#   'the',
#   'playing',
#   'being',
#   'doing'],
#  'coming': ['hello', 'um…', 'you', 'to', 'true'],
#  'we': ['are',
#   'were',
#   'were',
#   'were',
#   'had',
#   'had…',
#   'had',
#   'were',
#   'were',
#   'spend',
#   'need',
#   'both',
#   'like',
#   'like',
#   'do',
#   'do',
#   'pay',
#   'do',
#   'eat',
#   'eat',
#   'eat',
#   'do…',
#   'are',
#   'have',
#   'got',
#   'as',
#   'had',
#   'could',
#   'don’t',
#   'better',
#   'could',
#   'have',
#   'had',
#   'walk',
#   'just',
#   'all',
#   'don’t',
#   'live',
#   'wouldn’t',
#   'got',
#   'got',
#   'bought',
#   'die'],
#  'are': ['gonna',
#   'shocked',
#   'very',
#   'the',
#   'the',
#   'both',
#   'big',
#   'white',
#   'always',
#   'free',
#   'you',
#   'you',
#   'ceos',
#   'never',
#   'like',
#   'a',
#   'you',
#   'you',
#   'like',
#   'your',
#   'droppin’',
#   'in',
#   'you'],
#  'gonna': ['have',
#   'turn',
#   'die…',
#   'overtake',
#   'have',
#   'trap',
#   'propose…',
#   'stick',
#   'recognize',
#   'see',
#   'be',
#   'have',
#   'live',
#   'tell',
#   'happen',
#   'have',
#   'become–',
#   'disappear',
#   'become',
#   'have',
#   'before',
#   'make',
#   'be',
#   'recycle…',
#   'burn',
#   'be',
#   'poop',
#   'be'],
#  'have': ['to',
#   'to',
#   'a',
#   'insomnia',
#   'to',
#   'their',
#   'hpv',
#   'it',
#   'hpv',
#   'hpv',
#   'one',
#   'the',
#   'the',
#   'a',
#   'a',
#   'to',
#   'a',
#   'a',
#   'these',
#   'done',
#   'been',
#   'any',
#   'so',
#   'to',
#   'your',
#   'to',
#   'to',
#   'executive',
#   'some',
#   'a',
#   'a',
#   'a',
#   'had',
#   'children',
#   'any',
#   'a',
#   'to',
#   'a',
#   'sex',
#   'to',
#   'had',
#   'to',
#   'the',
#   'a'],
#  'get': ['this',
#   'it',
#   'it',
#   'rid',
#   'it',
#   'to',
#   'to',
#   'to',
#   'the',
#   'very',
#   'very',
#   'to',
#   'to',
#   'my',
#   'sicker',
#   'sicker',
#   'really',
#   'a',
#   'a',
#   'all',
#   'us',
#   'to',
#   'pregnant',
#   'pregnant',
#   'up',
#   'into',
#   'older',
#   'as',
#   'a',
#   'pregnant',
#   'pregnant',
#   'that…',
#   'my',
#   'pregnant',
#   'huge',
#   'dark',
#   'big–',
#   'big',
#   'all',
#   'pregnant'],
#  'this': ['shit',
#   'year',
#   'doctor',
#   'shit',
#   'shit',
#   'calculator',
#   'judy',
#   'shit',
#   'past',
#   'past',
#   'wedding',
#   'dude',
#   'guy',
#   'restaurant',
#   'restaurant',
#   'hippydippy',
#   'sneaking',
#   'wacky',
#   'dude',
#   'dude',
#   'bitch',
#   'huge',
#   'shit',
#   'conversation',
#   'is',
#   'fucking',
#   'relatable',
#   'is',
#   'left',
#   'red',
#   'huge',
#   'aggressive',
#   'shit”',
#   'shit',
#   'far',
#   'crazy',
#   'shit',
#   'dream'],
#  'shit': ['over',
#   'and',
#   'and',
#   'around',
#   'around',
#   'don’t',
#   'up',
#   'is',
#   'my',
#   'on',
#   'like',
#   'we',
#   'outta',
#   'in',
#   'in',
#   'in',
#   'too',
#   'was',
#   'together',
#   'together”',
#   'i',
#   'you’re',
#   'turns',
#   'it’s',
#   'you',
#   'out',
#   'that',
#   'over',
#   'at',
#   'on',
#   'around',
#   'anymore',
#   'that'],
#  'over': ['with', 'again', 'again', 'by', 'his'],
#  'with': ['’cause',
#   'the',
#   'where',
#   'your',
#   'all',
#   'these',
#   'a',
#   'a',
#   'a',
#   'somebody',
#   'a',
#   'glaucoma',
#   'our',
#   'this',
#   'my',
#   'him',
#   'him',
#   'me',
#   'their',
#   'the',
#   'which',
#   'me',
#   'the',
#   'eyelashes',
#   'my',
#   'a',
#   'male',
#   'your',
#   'no',
#   'me',
#   'it',
#   'you',
#   'intention',
#   'me',
#   'your',
#   'my'],
#  '’cause': ['i',
#   'it',
#   'it',
#   'my',
#   'you’re',
#   'when',
#   'her',
#   'it’s',
#   'you',
#   'i'],
#  'i': ['have',
#   'turned',
#   'appreciate',
#   'can',
#   'see',
#   'don’t',
#   'have',
#   'have',
#   'have',
#   'can',
#   'turn',
#   'am',
#   'turn',
#   'have',
#   'was',
#   'was',
#   'was',
#   'do',
#   'grew',
#   'also',
#   'gave',
#   'dated',
#   'first',
#   'saw',
#   'was',
#   'learned',
#   'was',
#   'trapped',
#   'did',
#   'knew',
#   'was',
#   'thought',
#   'was',
#   'saw',
#   'was',
#   'knew',
#   'was',
#   'dropped',
#   'was',
#   'don’t',
#   'get',
#   'mean',
#   'just',
#   'could',
#   'think',
#   'was',
#   'don’t',
#   'go',
#   'have',
#   'read',
#   'was',
#   'pee',
#   'need',
#   'grew',
#   'are',
#   'had',
#   'just',
#   'had',
#   'just',
#   'wanted',
#   'sent',
#   'told',
#   'bought',
#   'had',
#   'was',
#   'was',
#   'was',
#   'need',
#   'was',
#   'did',
#   'don’t',
#   'don’t',
#   'straight',
#   'don’t',
#   'do',
#   'don’t',
#   'don’t',
#   'wanna',
#   'want',
#   'think',
#   'guess',
#   'hear',
#   'wanna',
#   'love',
#   'love',
#   'still',
#   'gotta',
#   'literally',
#   'had',
#   'hear',
#   'lose',
#   'heard',
#   'was',
#   'know',
#   'heard',
#   'wanna',
#   'was',
#   'should',
#   'trapped',
#   'choose',
#   'chose',
#   'said',
#   'really',
#   'don’t',
#   'got',
#   'got',
#   'think',
#   'started',
#   'was',
#   'went',
#   'don’t',
#   'was',
#   'finally',
#   'just',
#   'got',
#   'was',
#   'got',
#   'just',
#   'don’t–',
#   'don’t',
#   'don’t',
#   'like',
#   'respect',
#   'know',
#   'don’t',
#   'also',
#   'just',
#   'can’t',
#   'can',
#   'told',
#   'want',
#   'wanna',
#   'can',
#   'want',
#   'want',
#   'wanna',
#   'have',
#   'don’t',
#   'am',
#   'dare',
#   'just',
#   'identify”',
#   'don’t',
#   'was',
#   'won',
#   'was',
#   'really',
#   'changed',
#   'get',
#   'need',
#   'don’t',
#   'need',
#   'get',
#   'need',
#   'get',
#   'say',
#   'mean',
#   'also',
#   'know',
#   'slime',
#   'don’t',
#   'did',
#   'was',
#   'ate',
#   'found',
#   'had',
#   'would',
#   'had',
#   'had',
#   'want',
#   'wanna',
#   'smell',
#   'smell',
#   'discretely',
#   'were',
#   'would',
#   'would',
#   'need',
#   'want',
#   'was',
#   'would',
#   'would',
#   'know',
#   'could',
#   'would',
#   'would',
#   'learned',
#   'would',
#   'don’t',
#   'had',
#   'can’t',
#   'wish',
#   'told',
#   'told',
#   'had',
#   'found',
#   'see',
#   'was',
#   'don’t',
#   'was',
#   'lost',
#   'sat',
#   'sat',
#   'was',
#   'used',
#   'wanted',
#   'love',
#   'finally',
#   'always',
#   'was',
#   'look',
#   'can’t',
#   'can',
#   'am',
#   'didn’t',
#   'can',
#   'can’t',
#   'get',
#   'do',
#   'like',
#   'berate',
#   'really',
#   'have',
#   'gotta',
#   'didn’t',
#   'didn’t',
#   'look',
#   'will',
#   'do',
#   'was',
#   'was',
#   'looked',
#   'in–',
#   'met',
#   'had',
#   'meet',
#   'discovered',
#   'don’t'],
#  'pee': ['in', 'i', 'on'],
#  'in': ['like',
#   'peace',
#   'men',
#   'women’s',
#   'the',
#   'books',
#   'the',
#   'handy',
#   'san',
#   'eight',
#   'a',
#   'san',
#   'broad',
#   'the',
#   'a',
#   'america',
#   'a',
#   'my',
#   'it',
#   'the',
#   'and',
#   'men',
#   '',
#   'my',
#   'well',
#   'ok',
#   'her',
#   'terms',
#   'a',
#   'a',
#   'their',
#   'doo',
#   'the',
#   'the',
#   'the',
#   'her',
#   'different',
#   'my',
#   'time”',
#   'the',
#   'the',
#   'his',
#   'his',
#   'bed',
#   'control',
#   'the',
#   'has',
#   'elementary',
#   'the',
#   'their–',
#   'a',
#   'between',
#   'my',
#   'front',
#   'the',
#   'your',
#   'your',
#   'such',
#   'the',
#   'atlanta',
#   'their',
#   'front',
#   'my',
#   'labor',
#   'the',
#   'front',
#   'our',
#   'shape',
#   'a',
#   'debt'],
#  'like': ['ten',
#   'shit',
#   'to',
#   'fifty',
#   'the',
#   '',
#   'this',
#   'the',
#   '“you',
#   '“but…',
#   '“oh',
#   '“oh',
#   '“all',
#   'we',
#   '“hey',
#   '“wassup”',
#   '“hey',
#   '“where”',
#   '“at',
#   '“oh',
#   'you',
#   'to',
#   'you’re',
#   'voting',
#   'that',
#   'i’m',
#   '“i',
#   'you',
#   '“hold',
#   'making',
#   'a',
#   '“i',
#   'loofah',
#   'responsibility',
#   'host',
#   'filipino',
#   '“it’s',
#   '“it’s',
#   'private',
#   'to',
#   'to',
#   'that',
#   'freerange',
#   'we',
#   'we',
#   '“oh',
#   '“i’m',
#   '“shut',
#   '“oh',
#   'you',
#   'very',
#   '“we’re',
#   '“we',
#   '“but',
#   '“look',
#   '“that',
#   'you’re',
#   'wiping',
#   '“oh',
#   'it’s',
#   '“you',
#   '“hey',
#   '“why',
#   'mrs',
#   '“uh',
#   '“oh',
#   'you’re',
#   'i',
#   '“oh',
#   'i’m',
#   'a',
#   'it',
#   'that',
#   'he’s',
#   'you’re',
#   '“yes',
#   'to',
#   '“i',
#   'become',
#   'a',
#   'a',
#   '“guys',
#   '“that’s',
#   '“ali',
#   '“yeah',
#   '“why',
#   '“yeah',
#   'a',
#   '“yeah',
#   '“oh',
#   '“i’m',
#   'the',
#   'i’m',
#   'skittles',
#   'a',
#   'everything',
#   '“oh',
#   'only',
#   '“we’re',
#   '‘release',
#   'a',
#   'we',
#   '“ok',
#   'they',
#   '“hey',
#   '“oh',
#   '“uh',
#   'losing',
#   '“no”',
#   '“yes”',
#   '“you',
#   '“yeah',
#   'that',
#   'this',
#   'i',
#   'a',
#   'a',
#   'fingers',
#   '“you',
#   'whoppers',
#   'a',
#   'when',
#   'really',
#   '“why',
#   'way'],
#  'ten': ['minutes', 'gallons'],
#  'minutes': ['but'],
#  'but': ['thank',
#   'fuck',
#   'my',
#   'i',
#   'he',
#   'sometimes',
#   'i',
#   'it’s',
#   'don’t',
#   'i',
#   'i',
#   'i’m',
#   'my',
#   'he’s',
#   'mostly',
#   'i’m',
#   'it’s'],
#  'everybody': ['so',
#   'has',
#   'has',
#   'has',
#   'thought',
#   'doesn’t',
#   'thought',
#   'thank'],
#  'so': ['much',
#   'basically',
#   'you',
#   'emotional',
#   'emotional',
#   'i',
#   'much',
#   'vulnerable',
#   'smooth',
#   'we’re',
#   'he',
#   'it’s',
#   'you',
#   'you’re',
#   'that',
#   'good',
#   'i',
#   'many',
#   'that',
#   'that',
#   'when',
#   'in',
#   'that',
#   'in',
#   'motherfucker',
#   'do',
#   'now',
#   'i',
#   'annoying',
#   'i',
#   'that',
#   'embarrassing',
#   'lonely',
#   'juicy',
#   'my',
#   'then',
#   'then',
#   'hot',
#   'that',
#   'tired',
#   'dark',
#   'they',
#   'bad',
#   'bad',
#   'resentful',
#   'much',
#   'you',
#   'little',
#   'little',
#   'supportive”',
#   'i',
#   'that',
#   'that',
#   'that',
#   'you',
#   'as'],
#  'much': ['for',
#   'better',
#   'chemistry',
#   'i',
#   'shittier',
#   'netflix',
#   'for',
#   'resentment'],
#  'um…': ['it’s', 'yeah'],
#  'it’s': ['a',
#   'been',
#   'like',
#   'ok',
#   'coming',
#   'undetectable',
#   'really',
#   'a',
#   'very',
#   'hot',
#   'what',
#   'like',
#   'so',
#   'all',
#   'different',
#   'funny',
#   'too',
#   'a',
#   'a',
#   'probably',
#   'basically',
#   'been',
#   'very',
#   'because',
#   'ok',
#   'like',
#   'like',
#   'the',
#   'because',
#   'sexist',
#   'very',
#   'so',
#   'a',
#   'a',
#   'what',
#   'lonely',
#   'a',
#   'very',
#   'all',
#   'too',
#   'easter',
#   'like',
#   'go',
#   'not',
#   'because',
#   'when',
#   'super',
#   'whatevs',
#   'different',
#   'not',
#   'straight',
#   'neosporin'],
#  'a': ['very',
#   'very',
#   'shit',
#   'sixpack',
#   'ambien',
#   'meditation',
#   'fucking',
#   'lot',
#   'ghost',
#   'selfhelp',
#   'horrible',
#   'hoarding',
#   'hoarding',
#   'third',
#   'dictator’s',
#   'shovel',
#   'climax',
#   'texas',
#   'procrastinator',
#   'lot',
#   'man',
#   'lot',
#   'lot',
#   'grownass',
#   'mattress',
#   'kitchen',
#   'very',
#   'catch',
#   'secret',
#   'public',
#   'hipster',
#   'homeless',
#   'lot',
#   'lot',
#   'major',
#   'yoko',
#   'white',
#   'white',
#   'wes',
#   'lot',
#   'white',
#   'white',
#   'dolphin',
#   'slip',
#   'jewish',
#   'huge',
#   'number',
#   'supply',
#   'grandma',
#   'weekend',
#   'shitty',
#   'woman',
#   'new',
#   'man',
#   'pinterest',
#   'saturday',
#   'completely',
#   'lot',
#   'lot',
#   'genius”',
#   'housewife',
#   'great',
#   'lot',
#   'great',
#   'office',
#   'office',
#   'office',
#   'day',
#   'sadass',
#   'macgyver',
#   'slow',
#   'lot',
#   'part',
#   'circle',
#   'lot',
#   'disgusting',
#   'pervert',
#   'gross',
#   'very',
#   'young',
#   'idiot',
#   'lot',
#   'result',
#   'little',
#   'second',
#   'whole',
#   'big',
#   'conqueror',
#   'little–',
#   'little',
#   'little',
#   'lot',
#   'lot',
#   'magical',
#   'big',
#   'ban',
#   'very',
#   'little',
#   'housewife',
#   'certain',
#   'couple',
#   'dude',
#   'stroll',
#   'sidewalk',
#   'quarter',
#   'princess',
#   'vietnam',
#   'half',
#   'female',
#   'baby',
#   'week',
#   'little',
#   'sudden',
#   'frozen',
#   'lot',
#   'lot',
#   'kid',
#   'kid',
#   'lot',
#   'kid',
#   'kid',
#   'asian',
#   'billion',
#   'turtle',
#   'right',
#   'uturn”',
#   'oturn”',
#   'car',
#   'mess',
#   'full',
#   'century',
#   'living',
#   'fuck',
#   'free',
#   'contest',
#   'kid',
#   'bubble',
#   'little',
#   'lot',
#   'smoker’s',
#   'side',
#   'sandwich',
#   'way',
#   'doctor',
#   'kid',
#   'lot',
#   'lot',
#   'while',
#   'bunch',
#   'dictatorship',
#   'hand',
#   'man',
#   'zombie',
#   'half',
#   'miscarriage',
#   'lot',
#   'miscarriage',
#   'third',
#   'pair',
#   'reason',
#   'heartbeat”',
#   'miscarriage',
#   'month',
#   'bike',
#   'doula',
#   'doula',
#   'white',
#   'lot',
#   'soft',
#   'baby',
#   'child',
#   'marriage',
#   'eyeball',
#   'foot',
#   'great',
#   'shitty',
#   'bad',
#   'daily',
#   'daily',
#   'bullseye',
#   'minion',
#   'year',
#   'nude',
#   'half',
#   'bunch',
#   'half',
#   'good'],
#  'very': ['exciting',
#   'exciting',
#   'helpful',
#   'lucky',
#   'unusual',
#   'confusing…',
#   'picturesque',
#   'you',
#   'underrated',
#   'well',
#   'surprised',
#   'soft',
#   'nurturing',
#   'domestic',
#   'upset',
#   'judgmental',
#   'distracting',
#   'young',
#   'sexually',
#   'roundabout',
#   'rare',
#   'demoralizing',
#   'clinical',
#   'universal',
#   'grateful',
#   'common',
#   'early',
#   'much',
#   'very',
#   'scared'],
#  'exciting': ['day', 'year'],
#  'day': ['for',
#   'yeah',
#   'and',
#   'was',
#   'getting',
#   'jobs',
#   'which',
#   'housewives',
#   'every',
#   'long',
#   'looks',
#   'this',
#   'since',
#   'long',
#   'on'],
#  'me': ['it’s',
#   'i',
#   'that',
#   'tony',
#   'that',
#   'to',
#   'something',
#   'he’s',
#   'off”',
#   'feel',
#   'and',
#   'to',
#   'feel',
#   'the',
#   'tell',
#   '‘cause',
#   'about',
#   'with',
#   'when',
#   'anymore',
#   'and',
#   'to',
#   'and',
#   'this',
#   'on',
#   'when–',
#   'this',
#   'and',
#   'ok”',
#   'i',
#   'enough',
#   'you',
#   'discouraged',
#   'from',
#   'when',
#   'from',
#   'because',
#   'see',
#   'of',
#   'but',
#   'company',
#   'when',
#   'i',
#   'when',
#   'anymore',
#   'like',
#   'extremely',
#   'because',
#   'in',
#   'that’s',
#   '“oh',
#   'while',
#   'and',
#   'to',
#   'a',
#   'out',
#   'out',
#   'to',
#   '“oh',
#   'i’m',
#   'i’m',
#   'i',
#   'money',
#   'in',
#   'for',
#   'out',
#   'oh',
#   'with',
#   'how',
#   'oh'],
#  'been': ['a',
#   'dating',
#   'pressuring',
#   'together',
#   'reading',
#   'to',
#   'run',
#   'eating',
#   'trying',
#   'ali'],
#  'year': ['for', 'yes', 'uh', 'i', 'i’ve', 'i', 'i'],
#  'turned': [''],
#  '': ['this',
#   'girl',
#   'girls',
#   'is',
#   'probably',
#   'and',
#   'percent',
#   'to',
#   'percent',
#   'imports',
#   'i',
#   'and',
#   'whole',
#   'going',
#   'which',
#   'and…',
#   'years',
#   'and',
#   'i',
#   'ok',
#   'and',
#   'flip',
#   'girl',
#   'you’ll',
#   'days',
#   'days',
#   'years',
#   'in'],
#  'yes': ['thank', 'yes', 'that’s', 'yes', 'yes', 'i', 'because'],
#  'five': ['people', 'years', 'years'],
#  'people': ['i',
#   'inside',
#   'are',
#   'it’s…',
#   'all',
#   'don’t',
#   'until',
#   'doing',
#   'like',
#   'are',
#   'i',
#   'that’s',
#   'were',
#   'praise',
#   'don’t',
#   'will'],
#  'appreciate': ['that'],
#  'that': ['uh',
#   'i’m',
#   'huge',
#   'says',
#   'they',
#   'lives',
#   'i',
#   'i’m',
#   'if',
#   'you',
#   'retainer',
#   'with',
#   'calculator',
#   'bamboozled',
#   'i’m',
#   'will',
#   'at',
#   'he',
#   'your',
#   'store',
#   'beard',
#   'shit',
#   'and',
#   'privilege',
#   'entitlement…',
#   'for',
#   'you',
#   'uh',
#   'bread',
#   'tastes',
#   'lesbian',
#   'seems',
#   'seems',
#   'he',
#   'you’re',
#   'i',
#   'i',
#   'so',
#   'he’d',
#   'book',
#   'book',
#   'got',
#   'ever',
#   'we’ll',
#   'fucking',
#   'housewife',
#   'horrible',
#   'they',
#   'oneply',
#   'office',
#   'they',
#   'your',
#   'the',
#   'no',
#   'shit',
#   'you',
#   'don’t',
#   'i',
#   'if',
#   'i’m',
#   'he’s',
#   'and',
#   'you',
#   'if',
#   'then',
#   'they’re',
#   'fear',
#   'shit',
#   'fear',
#   'he',
#   'we',
#   'i’m',
#   'i',
#   'woman',
#   'now',
#   'whole',
#   '',
#   'was',
#   'was',
#   'baby’s',
#   'everybody',
#   'it’s',
#   'came',
#   'she’s',
#   '’cause',
#   'to',
#   'you',
#   'snailtrail',
#   'my',
#   'were',
#   'it',
#   'it’s',
#   'tell',
#   'i',
#   'when',
#   'means',
#   'they',
#   'they',
#   'day',
#   'says',
#   'stupidass',
#   'i',
#   'harvard',
#   'they’re',
#   'i',
#   'shit',
#   'is',
#   'you’re',
#   'you–',
#   'that',
#   'happens',
#   'he',
#   'he’s',
#   'goes',
#   'i',
#   'they',
#   'the',
#   'the',
#   'i’m',
#   'my'],
#  'uh': ['i', 'this', 'he’s–', 'between', 'you', 'we', 'i’m', 'two'],
#  'can': ['tell',
#   'also',
#   'i',
#   'i',
#   'never',
#   'you',
#   'be',
#   'tell',
#   'tell',
#   'never',
#   'listen',
#   'do',
#   'talk',
#   'comfortably',
#   'tell',
#   'just',
#   'think',
#   'i',
#   'i',
#   'i',
#   'already',
#   'really',
#   'you',
#   'already',
#   'see',
#   'find'],
#  'tell': ['that',
#   'that',
#   'first',
#   'by',
#   'you',
#   'them',
#   'me',
#   'you',
#   'you',
#   'but',
#   'you',
#   'because',
#   'you'],
#  'i’m': ['getting',
#   'straight',
#   'jealous',
#   'gonna',
#   'getting',
#   'not',
#   'interested',
#   'a',
#   'not',
#   'hoping',
#   'hoping',
#   'gonna',
#   'not',
#   'the',
#   'gonna',
#   'absorbing',
#   'like',
#   'halfchinese',
#   'halfchinese',
#   'a',
#   'very',
#   'like',
#   'done”',
#   'done',
#   'not',
#   'a–',
#   'a',
#   'a',
#   'a',
#   'scared',
#   'a',
#   'going',
#   'like',
#   'gonna',
#   'gonna',
#   'tired',
#   'the',
#   'the',
#   'just',
#   'talking',
#   'talking',
#   'striving',
#   'a',
#   'a',
#   'guaranteed',
#   'still',
#   'just',
#   'older',
#   'not',
#   'only',
#   'only',
#   'gonna',
#   '',
#   'very',
#   '',
#   'from',
#   'scared',
#   'very',
#   'going',
#   'all',
#   'busy',
#   'the',
#   'not',
#   'a',
#   'fucked',
#   'not',
#   'seven',
#   'performing'],
#  'getting': ['older', 'older', 'busy', 'massages'],
#  'older': ['because', 'because', 'it’s', 'when'],
#  'because': ['now',
#   '',
#   'it’s',
#   'my',
#   'my',
#   'you',
#   'what',
#   'according',
#   'before',
#   'i',
#   'usually',
#   'being',
#   'he’s',
#   'he’s',
#   'you',
#   'i',
#   'you',
#   'i',
#   'the',
#   'he',
#   'you',
#   'we’re',
#   'i’m',
#   'of',
#   'according',
#   'boys',
#   'female',
#   'they',
#   'i’m',
#   'we’re',
#   'uh',
#   'when',
#   'they’re',
#   'they’re',
#   'then',
#   'the',
#   'we’re',
#   'last',
#   'when',
#   'the',
#   'i',
#   'if',
#   'my–',
#   'he'],
#  'now': ['when',
#   'has',
#   'crush',
#   'for',
#   'we’re',
#   'but',
#   'if',
#   'because',
#   'instead',
#   'and',
#   'that',
#   'if'],
#  'when': ['i',
#   'they',
#   'a',
#   'you’re',
#   'she',
#   'we',
#   'you',
#   'you',
#   'really',
#   'i',
#   'you’re',
#   'a',
#   'i',
#   'you',
#   'i',
#   'our',
#   'you',
#   'we',
#   'i',
#   'i',
#   'i',
#   'i',
#   'you',
#   'he',
#   'i',
#   'that',
#   'i’ve',
#   'you',
#   'you’re',
#   'they',
#   'i',
#   'i’m',
#   'i',
#   'i',
#   'my',
#   'you',
#   'trying',
#   'i',
#   'everything',
#   'i',
#   'can',
#   'can',
#   'my',
#   'in–',
#   'you’re',
#   'the',
#   'it’s',
#   'it',
#   'they',
#   'i',
#   'somebody',
#   'somebody',
#   'he',
#   'a',
#   'they',
#   'they',
#   'you’re',
#   'they',
#   'i',
#   'i',
#   'they’re',
#   'you’re',
#   'you',
#   'he',
#   'you',
#   'i',
#   'it',
#   'it’s',
#   'it’s'],
#  'see': ['an',
#   'ten',
#   'on',
#   'that',
#   'the',
#   'a',
#   'a',
#   'how',
#   'that',
#   'who’s',
#   'a',
#   'the',
#   'the',
#   'two',
#   'is',
#   'beyoncé',
#   'how',
#   'how',
#   'if',
#   'like',
#   'me'],
#  'an': ['', 'atm', 'impression', 'investment'],
#  'girl': ['my', 'because', 'when'],
#  'my': ['automatic',
#   'doctor',
#   'body',
#   'kindle',
#   'home',
#   'optimum',
#   'other',
#   'mom',
#   'life',
#   'generation',
#   'time',
#   'mom',
#   'optimum',
#   'husband',
#   'league',
#   'god',
#   'god',
#   'part',
#   'generation',
#   'volvo',
#   'husband',
#   'pussy',
#   'god',
#   'husband',
#   'god',
#   'bed',
#   'husband',
#   'god',
#   'pinterest',
#   'best',
#   'wedding',
#   'husband',
#   'personality',
#   'heart',
#   'financial',
#   'friends',
#   'coworkers',
#   'toilet',
#   'fingers',
#   'coworkers',
#   'coworkers',
#   'shit',
#   'fatherinlaw',
#   'husband',
#   'life',
#   'destiny',
#   'last',
#   'mom',
#   'dad',
#   'grandma”',
#   '',
#   'god',
#   'god',
#   'husband',
#   'husband',
#   'asianamerican',
#   'female',
#   'friends',
#   'husband',
#   'mind',
#   'mind',
#   'god',
#   'face',
#   'toyota',
#   'mom',
#   'husband',
#   'destiny',
#   'body',
#   'god',
#   'fault',
#   '',
#   'uterus',
#   'progesterone',
#   'writing',
#   'coworkers',
#   'underwear',
#   'fingers',
#   'fingers',
#   'own',
#   'fingers',
#   'fingers',
#   'fingers”',
#   'husband',
#   'god',
#   'husband',
#   'face',
#   'god',
#   'mom–',
#   'sixweek',
#   'god',
#   'husband',
#   'miscarriage',
#   'shit',
#   'husband',
#   'husband',
#   'doctor’s',
#   'god',
#   'blood',
#   'husband',
#   'nipples',
#   'pussy’s',
#   'pussy’s',
#   'body’s',
#   'husband',
#   'league',
#   'god',
#   'dreams',
#   'beautiful',
#   'hardearned',
#   'ass'],
#  'automatic': ['thought…'],
#  'thought…': ['is'],
#  'is': ['“fuck',
#   'a',
#   'turning',
#   'all',
#   'the',
#   'from',
#   'those',
#   'it',
#   'that”',
#   'a',
#   'a',
#   'that',
#   'asian',
#   'turning',
#   'that',
#   'built',
#   'all',
#   'the',
#   'too',
#   'like',
#   'always',
#   'called',
#   'the',
#   'a',
#   'to',
#   'that…',
#   'doo',
#   '“i',
#   'unfortunately',
#   'what',
#   'a',
#   'a',
#   'at',
#   'the',
#   'a',
#   '',
#   'so',
#   'not',
#   'not',
#   'not',
#   'most',
#   '“when',
#   'fine',
#   'very',
#   'about',
#   'very',
#   'very',
#   'a',
#   'mysterious”',
#   'you',
#   'that’s',
#   'so',
#   'it'],
#  '“fuck': ['you”', 'you'],
#  'you”': ['“fuck', '‘cause', 'my'],
#  'don’t': ['even',
#   'have',
#   'know',
#   'have',
#   'have',
#   'have',
#   'know',
#   'ever',
#   'even',
#   'know',
#   'know',
#   'gotta',
#   'know',
#   'go',
#   'got',
#   'wanna',
#   'i',
#   'wanna',
#   'feed',
#   'wanna',
#   'wanna',
#   'know',
#   'think',
#   'gotta',
#   'gotta',
#   'gotta…',
#   'gotta',
#   'gotta',
#   'gotta',
#   'gotta',
#   'gotta',
#   'gotta',
#   'try',
#   'your',
#   'wanna',
#   'wanna',
#   'worry',
#   'cheat',
#   'i',
#   'no”',
#   'wanna',
#   'kill',
#   'wanna',
#   'want',
#   'know',
#   'get',
#   'know',
#   'you',
#   'crack”',
#   'die',
#   'die',
#   'know',
#   'give',
#   'know',
#   'wanna',
#   'see',
#   'feel',
#   'tell',
#   'work'],
#  'even': ['know', 'know…', 'accidentally', 'effective', 'have', 'come'],
#  'know': ['you',
#   'what',
#   'that',
#   'when',
#   'what',
#   'when',
#   'wear',
#   'what’s',
#   'because',
#   'you',
#   'white',
#   'it’s',
#   'just',
#   'why',
#   'oohwee',
#   'the',
#   'learning',
#   'anything',
#   'what',
#   'i',
#   'that',
#   'maybe',
#   'how',
#   'how',
#   'you',
#   'squeeze',
#   'it’s–',
#   'that',
#   'i',
#   'and',
#   'especially',
#   'my',
#   'i',
#   'you',
#   'like',
#   'i',
#   'i',
#   'what',
#   'you’ve',
#   'what',
#   'if',
#   'what’s',
#   'a',
#   'the',
#   'why',
#   'what’s',
#   'i',
#   'is',
#   'what',
#   'and',
#   'what',
#   'plenty',
#   'what',
#   'what',
#   'that',
#   'i–',
#   'your',
#   'that',
#   'that',
#   'they',
#   'and',
#   'i–'],
#  'fuck': ['you”', 'they', 'up', 'down', 'one', 'they', 'him', 'up”', 'i'],
#  '‘cause': ['i’m', 'he', 'i', 'it’s', 'if', 'she', 'i'],
#  'straight': ['up', 'up', 'up'],
#  'up': ['jealous',
#   'hpv',
#   'yes',
#   'your',
#   'when',
#   'a',
#   'on',
#   'with',
#   'in',
#   'afterwards',
#   'on',
#   'like',
#   'going',
#   'for',
#   'on',
#   'and',
#   'fine',
#   'don’t',
#   'about',
#   'a',
#   'to',
#   'a',
#   'to',
#   'with',
#   'you',
#   'so',
#   'there',
#   'on',
#   'she’s',
#   'the',
#   'myself',
#   'from',
#   'your',
#   'and',
#   'soldier'],
#  'jealous': ['i’m', 'first'],
#  'first': ['and',
#   'met',
#   'thing',
#   'dates',
#   'and',
#   'passively',
#   'you’ll',
#   'lady',
#   'old',
#   'webmd',
#   'home'],
#  'foremost': ['of', 'by'],
#  'of': ['their',
#   'potential',
#   'regret',
#   'them',
#   'men',
#   'two',
#   'hpv',
#   'wolverine',
#   'grey',
#   'tidying',
#   'success',
#   'all',
#   'my',
#   'shit',
#   'my',
#   'a',
#   'you',
#   'my',
#   'success”',
#   'losers',
#   'losers',
#   'skaters',
#   'my',
#   'my',
#   'people',
#   'opinions',
#   'cool',
#   'that',
#   'that',
#   'your',
#   'our',
#   'our',
#   'los',
#   'all',
#   'bleach',
#   'your',
#   'this',
#   'asian',
#   'us',
#   'the',
#   'my',
#   'facebook',
#   'women',
#   'options',
#   'my',
#   'day',
#   'the',
#   'the',
#   'their',
#   'credence',
#   'my',
#   'privileged',
#   'this',
#   'my',
#   'early',
#   'myself',
#   'women',
#   'the',
#   'the',
#   'crazy',
#   'the',
#   'is',
#   'your',
#   'mine',
#   'resistance',
#   '“no',
#   'the',
#   'control',
#   'control',
#   'being',
#   'her',
#   'saying',
#   'saying',
#   'income',
#   'one',
#   'them',
#   'shit',
#   'a',
#   'my',
#   'my',
#   'your',
#   'nowhere',
#   'their',
#   'her',
#   'those',
#   'longevity',
#   'change',
#   'mother',
#   'science',
#   'that…',
#   'my',
#   'the',
#   'people',
#   'fuckin’”',
#   'the',
#   'that',
#   'angry',
#   'the',
#   'the',
#   'your',
#   'their',
#   'their',
#   'him…',
#   'this',
#   'that',
#   'me',
#   'women',
#   'women',
#   'shoes',
#   'poppy',
#   'me',
#   'craigslist',
#   'childbirth',
#   'women',
#   'the',
#   'your',
#   'life',
#   'how',
#   'my',
#   'the',
#   'survival',
#   'another',
#   'those',
#   'body',
#   'losers',
#   'my',
#   'whitecollar'],
#  'their': ['metabolism',
#   'feet',
#   'whole',
#   'house',
#   'communist',
#   'shit',
#   'doo',
#   'hallways',
#   'ipad',
#   'eyebrows',
#   'prostate',
#   'fame',
#   'existence',
#   'bigass',
#   'darth',
#   'archnemesis',
#   'in',
#   'eyes',
#   'eyes',
#   'eyes',
#   'head',
#   'eyelids',
#   'face…',
#   '',
#   'husbands'],
#  'metabolism': ['because'],
#  'girls': ['they'],
#  'they': ['could',
#   'take',
#   'got',
#   'put',
#   'go',
#   'just',
#   'don’t',
#   'don’t',
#   'have',
#   'don’t',
#   'just',
#   'have',
#   'were',
#   'like',
#   'teach',
#   'introduce',
#   'got',
#   'just',
#   'get',
#   'mean',
#   'ruined',
#   'don’t',
#   'don’t',
#   'don’t',
#   'don’t',
#   'don’t',
#   'purposely',
#   'try',
#   'don’t',
#   'don’t',
#   'don’t',
#   'want',
#   'don’t',
#   'can',
#   'can',
#   'wantyou',
#   'say',
#   'would',
#   'wax',
#   'do',
#   'get',
#   'like',
#   'just',
#   'just',
#   'do',
#   'generally',
#   'have',
#   'become',
#   'were',
#   'were',
#   'were',
#   'don’t',
#   'got',
#   'do',
#   'do',
#   'wear',
#   'can',
#   'just',
#   'make',
#   'watch',
#   'come',
#   'just',
#   'need',
#   'saw',
#   'get',
#   'look',
#   'just',
#   'hear',
#   'wouldn’t',
#   'go',
#   'were',
#   'tried',
#   'get',
#   'get',
#   'get',
#   'get'],
#  'could': ['just',
#   'graph',
#   'just',
#   'just',
#   'have',
#   'do',
#   'do',
#   'ask',
#   'just',
#   'just',
#   'always'],
#  'just': ['eat',
#   'radiating',
#   'go',
#   'cluttering',
#   'go',
#   'fucked',
#   'feel',
#   'right',
#   'crush',
#   'kill',
#   'like',
#   'black',
#   'smell',
#   'had',
#   'had',
#   'gonna',
#   'nag',
#   'stay',
#   'walking',
#   'dehydrates',
#   'blow',
#   'fulfilling',
#   'put',
#   'felt',
#   'wanted',
#   'sneak',
#   'give',
#   'give',
#   'see',
#   'become',
#   'not',
#   'wanna',
#   'want',
#   'wanna',
#   'wanna',
#   'choke',
#   'waiting',
#   'keep',
#   'try',
#   'had',
#   'swells',
#   'gonna',
#   'travel',
#   'do',
#   'kidding',
#   'gonna',
#   'sopping',
#   'took',
#   'reach',
#   'blow',
#   'scratch',
#   'vacuum',
#   'come',
#   'give',
#   'got',
#   'twerk',
#   'drain',
#   'shit',
#   'when'],
#  'eat': ['like', 'glutenfree', 'all', 'that', 'it', 'snacks', 'a', 'bananas”'],
#  'then': ['they',
#   'when',
#   'after',
#   'also',
#   'asian',
#   'if',
#   'afterwards',
#   'all',
#   'it',
#   'i',
#   'you',
#   'you',
#   'your',
#   'if',
#   'it',
#   'you',
#   'on',
#   'i',
#   'at',
#   'at',
#   'a',
#   'i',
#   'resist',
#   'he',
#   'when',
#   'because',
#   'i',
#   'i',
#   'she',
#   'you',
#   'i',
#   'we',
#   'we'],
#  'take': ['a', 'a', 'these', 'a', 'these', 'its'],
#  'sixpack': ['right'],
#  'right': ['they',
#   'they',
#   'that’s',
#   'so',
#   'how',
#   'ali',
#   'there',
#   'now',
#   'we',
#   'because',
#   'and',
#   'you',
#   'moment',
#   'turn–',
#   '‘cause',
#   'there',
#   'after',
#   'i’ve'],
#  'got': ['thatthat',
#   'so',
#   'married',
#   'no',
#   'a',
#   'me',
#   'engaged',
#   'women',
#   'married',
#   'married',
#   'a',
#   'married',
#   'a',
#   'no',
#   'bit',
#   'him',
#   'him',
#   'married',
#   'pregnant'],
#  'thatthat': ['beautiful'],
#  'beautiful': ['inner', 'harvardeducated'],
#  'inner': ['thigh', 'peace', 'evil'],
#  'thigh': ['clearance'],
#  'clearance': ['where'],
#  'where': ['they', 'my', 'i', 'the', 'the', 'i', 'i’m', 'if'],
#  'put': ['their', 'it', 'it', 'it'],
#  'feet': ['together'],
#  'together': ['and', 'you', 'now', 'they’ll', 'to', 'when', 'and'],
#  'there’s': ['that', 'this', 'multiple', 'like', 'nothing'],
#  'huge': ['gap', 'unspoken', 'sitdown', 'bear', 'and'],
#  'gap': ['here'],
#  'here': ['with', 'is', 'you'],
#  'light': ['of', 'completely”'],
#  'potential': ['just', 'why'],
#  'radiating': ['throughand'],
#  'throughand': ['then'],
#  'go': ['to',
#   'to',
#   'to',
#   'and',
#   'and',
#   'of',
#   'to',
#   'home…',
#   'for',
#   'on',
#   'very',
#   'back',
#   'call',
#   'home',
#   'paintballing',
#   'and',
#   'bald…',
#   'to',
#   'time”',
#   'through',
#   'to'],
#  'sleep': ['they', 'right', 'in'],
#  'insomnia': ['yet'],
#  'yet': ['they', 'they', 'you', 'you’re', 'and'],
#  'what': ['it’s',
#   'that',
#   'your',
#   'that',
#   'it',
#   'love',
#   'the',
#   'i',
#   'happens',
#   'you’re',
#   'he',
#   'to',
#   'i’m',
#   'else',
#   'everybody',
#   'kind',
#   'that',
#   'i',
#   'that',
#   'a'],
#  'ambien': ['or'],
#  'or': ['download',
#   'you’re',
#   'you',
#   'for',
#   'something',
#   'whatever',
#   'something…'],
#  'download': ['a'],
#  'meditation': ['oasis', 'retreats'],
#  'oasis': ['podcast'],
#  'podcast': ['to'],
#  'calm': ['the'],
#  'chatter': ['of'],
#  'regret': ['and'],
#  'resentment': ['towards', 'especially'],
#  'towards': ['your', 'my'],
#  'your': ['family',
#   'mind',
#   '',
#   'wealth',
#   'butt',
#   'mom',
#   'body',
#   'head',
#   'own',
#   'body',
#   'daily',
#   'butt',
#   'butt',
#   'coworker’s',
#   'shoes',
#   'butt',
#   'underwear',
#   'shit',
#   'children',
#   'understand',
#   'son',
#   'shame',
#   'inner',
#   'secrets',
#   'man',
#   'thumb',
#   'husband',
#   'lives',
#   'pussy',
#   'hand',
#   'pants',
#   'fingers',
#   'fingers',
#   'first',
#   '',
#   '',
#   'sperm',
#   'face',
#   'pussy',
#   'husband',
#   'leg',
#   'life',
#   'doctor’s',
#   'body',
#   'nipples'],
#  'family': ['just', 'would', 'funny'],
#  'cluttering': ['your'],
#  'mind': ['they', 'it’s', 'again'],
#  'whole': ['lives', 'manipulation', 'new', 'foods', 'foods', 'thing”'],
#  'lives': ['ahead', 'inside', 'with'],
#  'ahead': ['of'],
#  'them': ['they', 'they’re', 'the', 'nothing', 'once', 'they', 'up'],
#  'hpv': ['yet', 'ok', 'yet', 'because', 'is', 'either', 'will', 'very'],
#  'peace': ['at', 'and', 'sign'],
#  'at': ['night',
#   'home',
#   'this',
#   'the',
#   'golden',
#   'any',
#   'how',
#   'all',
#   'the',
#   'home',
#   'that',
#   'that',
#   'a',
#   'work',
#   'the',
#   'a',
#   'a',
#   'a',
#   'life',
#   'first',
#   'home',
#   'any',
#   'my',
#   'fresh',
#   'some',
#   'my',
#   'work',
#   'him',
#   'his'],
#  'night': ['everybody', 'you', 'and', 'everybody'],
#  'has': ['hpv',
#   'it',
#   'it',
#   'hpv',
#   'hosted',
#   'even',
#   'made',
#   'to',
#   'a',
#   'had',
#   'to'],
#  'ok': ['everybody',
#   'come',
#   'i’m',
#   'that',
#   'so',
#   'a',
#   'i',
#   'because',
#   'you',
#   'so',
#   'are',
#   'we',
#   'i',
#   'old',
#   'do',
#   'when',
#   'and',
#   'when',
#   'when',
#   'they',
#   'are'],
#  'it': ['it’s',
#   'if',
#   'yet',
#   'you',
#   'it’s',
#   'might',
#   'was',
#   'was',
#   'all',
#   'was',
#   'when',
#   'cost',
#   'was',
#   'could',
#   'was',
#   'on',
#   'happened',
#   'happened',
#   'you',
#   'can',
#   'you',
#   'on',
#   'don’t',
#   'second',
#   'was',
#   'you',
#   'so',
#   'on',
#   'on',
#   'as',
#   'so',
#   'we',
#   'for',
#   'a',
#   'basically',
#   'and',
#   'backfired',
#   'echo',
#   'in',
#   'in',
#   'in',
#   'up',
#   'up',
#   'interesting',
#   'in',
#   'was',
#   'before',
#   'tonight',
#   'that',
#   'might',
#   'sheryl',
#   'when',
#   'up',
#   'was',
#   'in',
#   'scared',
#   'used',
#   'for',
#   'was',
#   'just…',
#   'made',
#   'gets',
#   'tells',
#   'was',
#   'was',
#   'i',
#   'so',
#   'when',
#   'as',
#   'very',
#   'makes',
#   'takes',
#   'also',
#   'easier',
#   'now',
#   'was',
#   'different”',
#   'up',
#   'that’s',
#   'all',
#   'turns',
#   'how'],
#  'come': ['out', 'in', 'out', 'up', 'out', 'out', 'home', 'with', 'out'],
#  'out': ['already',
#   'um',
#   'of',
#   'there',
#   'of',
#   'they',
#   'and',
#   'they',
#   'at',
#   'about',
#   'down',
#   'of',
#   'of',
#   'of',
#   'first',
#   'that',
#   'of',
#   'it’s',
#   'like',
#   'of',
#   'of',
#   'when',
#   'at',
#   'they',
#   'about',
#   'and',
#   'yet',
#   'of',
#   'of',
#   'he’s'],
#  'already': ['everybody', 'see', 'so', 'see'],
#  'if': ['you',
#   'the',
#   'it',
#   'he',
#   'a',
#   'you',
#   'you',
#   'i',
#   'you’re',
#   'you',
#   'you',
#   'you',
#   'i',
#   'you',
#   'it’s',
#   'i’m',
#   'i',
#   'he',
#   'you',
#   'i',
#   'i'],
#  'you’re': ['a',
#   'in',
#   'busy',
#   'with',
#   'in',
#   'like',
#   'too',
#   'like',
#   'about',
#   'paranoid',
#   'like',
#   'a',
#   'not',
#   'really',
#   'scared',
#   'married',
#   'gonna',
#   'fucking',
#   'the',
#   'supposed',
#   'eating',
#   'gonna',
#   'gonna',
#   'in',
#   '',
#   'having',
#   'gonna',
#   'in'],
#  'fucking': ['loser', 'housewife', 'different', 'baby', 'baby'],
#  'loser': ['all'],
#  'all': ['right',
#   'about',
#   'of',
#   'your',
#   'came',
#   'required',
#   'because',
#   'this',
#   'his',
#   'of',
#   'of',
#   'the',
#   'up',
#   'fucked',
#   'red',
#   'you',
#   'that',
#   'of',
#   'over',
#   'with',
#   'riled',
#   'day',
#   'these',
#   'day',
#   'over',
#   'day',
#   'the',
#   'sorts',
#   'of',
#   'your',
#   'he’s',
#   'squirmy',
#   'right',
#   'the',
#   'the',
#   'my',
#   'these',
#   'of',
#   'know',
#   'of',
#   'the',
#   'the',
#   'day',
#   'you',
#   'good',
#   'of',
#   'the',
#   'backed',
#   'of',
#   'your',
#   'this',
#   'back',
#   'wet',
#   'wet',
#   'my',
#   'off',
#   'right'],
#  'that’s': ['what',
#   'gonna',
#   'right',
#   'what',
#   'not',
#   'where',
#   'right',
#   'like…',
#   'how',
#   'how',
#   'not',
#   'right',
#   'gonna',
#   'why',
#   'the',
#   'when',
#   'not',
#   'the',
#   'the',
#   'cool…',
#   'not',
#   'so',
#   'shit',
#   'right',
#   'so',
#   'like',
#   'my',
#   'why',
#   'a',
#   'enough',
#   'the',
#   'not'],
#  'says': ['about', '“boo”', '“please', 'to'],
#  'about': ['you',
#   'how',
#   'the',
#   'him',
#   'a',
#   'vietnamese',
#   'it',
#   'our',
#   'how',
#   'those',
#   'housewives',
#   'to',
#   'the',
#   'money',
#   'anal',
#   'is',
#   'i’m',
#   'that',
#   'is',
#   'to',
#   'to',
#   'it',
#   'giving',
#   'childbirth',
#   'all'],
#  'lot': ['of',
#   'this',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'i',
#   'more',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'more',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of'],
#  'men': ['don’t', 'it’s', 'are', 'are', 'no', 'we', 'as'],
#  'undetectable': ['in'],
#  'really': ['fucked',
#   'i’m',
#   'it’s',
#   'work',
#   'meant',
#   'you',
#   'scared',
#   'i',
#   'am”',
#   'take',
#   'am',
#   'hot'],
#  'fucked': ['up', 'a', 'up', 'so'],
#  'ghost': ['that'],
#  'inside': ['men’s', 'horrible', 'i', 'of'],
#  'men’s': ['bodies'],
#  'bodies': ['and', 'my'],
#  '“boo”': ['in'],
#  'women’s': ['bodies', 'intuition'],
#  'doctor': ['told', 'right', 'your', 'says', 'appointments'],
#  'told': ['me', 'her', 'you', 'my', 'her'],
#  'one': ['of', 'of', 'of', 'of', 'person', 'i', 'of', 'she', 'of', 'who'],
#  'two': ['strains', 'homeless', 'days', 'latina', 'sacks', 'weeks'],
#  'strains': ['of'],
#  'either': ['i', 'i’m'],
#  'kind': ['that’s', 'where', 'of', 'of', 'of', 'of'],
#  'turn': ['into', 'this', 'this', 'into', 'signal', 'upside'],
#  'into': ['cervical',
#   'a',
#   'the',
#   'a',
#   'the',
#   'banana',
#   'the',
#   'the',
#   'the',
#   'a',
#   'pleasure',
#   'a',
#   'my',
#   'your',
#   'a',
#   'the'],
#  'cervical': ['cancer…'],
#  'cancer…': ['…or'],
#  '…or': ['i'],
#  'body': ['will', 'is', 'hair', 'is', 'odor', 'was', 'when', 'where'],
#  'will': ['heal', 'also', 'also', 'you', 'always', 'be', 'have', 'commend'],
#  'heal': ['itself', 'from'],
#  'itself': ['very'],
#  'helpful': ['this'],
#  'basically': ['either', 'just', 'like'],
#  'die…': ['or'],
#  'presence': ['of'],
#  'wolverine': ['bitches'],
#  'bitches': ['we’ll', 'i'],
#  'we’ll': ['find', 'see'],
#  'find': ['out', 'a', 'ways', 'a', 'it'],
#  'um': ['i', 'and'],
#  'also': ['tell',
#   'disappear',
#   'got',
#   'last',
#   'he’s',
#   'don’t',
#   'decided',
#   'takes'],
#  'kindle': ['is'],
#  'turning': ['into', 'into'],
#  'selfhelp': ['library'],
#  'library': ['i’m'],
#  'not': ['interested',
#   'happy',
#   'trying',
#   'the',
#   'kissing',
#   'ask',
#   'authentic',
#   'recognize',
#   'doing',
#   'a',
#   'even',
#   'have',
#   'be',
#   'dieting',
#   'scared',
#   'as',
#   'the',
#   'again”',
#   'rush',
#   'trying',
#   'my',
#   'technically',
#   'as',
#   'ok',
#   'fuckin’',
#   'because',
#   'doing',
#   'there',
#   'gonna',
#   'like',
#   'the'],
#  'interested': ['in', 'in'],
#  'books': ['like'],
#  'fifty': ['shades'],
#  'shades': ['of'],
#  'grey': ['ok'],
#  'lifechanging': ['magic'],
#  'magic': ['of'],
#  'tidying': ['up'],
#  'how': ['to',
#   'can',
#   'can',
#   'proposals',
#   'did',
#   'rotten',
#   'offstage',
#   'we',
#   'to',
#   'much',
#   'invincible',
#   'a',
#   'there’s',
#   'it',
#   'did',
#   'did'],
#  'declutter': ['my'],
#  'home': ['to', 'in', 'all', 'and', 'chapping', 'and', 'together'],
#  'achieve': ['inner', 'my'],
#  'optimum': ['level', 'level'],
#  'level': ['of', 'of'],
#  'success': ['that’s'],
#  'around': ['i’m', 'help', 'together', 'all', 'they', 'to', 'the', 'by'],
#  'horrible': ['person', 'but', 'toilet'],
#  'person': ['i’m', 'you–', 'for'],
#  'happy': ['with'],
#  'am': ['how', 'seven', 'already', 'not', 'mad'],
#  'help': ['me', 'mei', 'her', 'you', 'as'],
#  'tony': ['robbins'],
#  'robbins': ['help'],
#  'mei': ['have'],
#  'hoarding': ['problem', 'goes', 'problem'],
#  'problem': ['which', 'because'],
#  'which': ['i’m',
#   'is',
#   'a',
#   'means',
#   'would',
#   'is…',
#   'means',
#   'their',
#   'is',
#   'is',
#   'he’s',
#   'i',
#   'is',
#   'is',
#   'is',
#   'means',
#   'subsequently'],
#  'hoping': ['is', 'that'],
#  'center': ['of'],
#  'other': ['problems', 'homeless', 'because', 'day', 'you', 'shitty'],
#  'problems': ['i’m'],
#  'goes': ['away', 'down'],
#  'away': ['the', 'anything', 'from', 'a', 'at'],
#  'disappear': ['i', 'that’s', 'and'],
#  'mom': ['is', 'it', 'got', 'my', 'is', 'is', 'people'],
#  'from': ['a',
#   'the',
#   'the',
#   'the',
#   'the',
#   'pier',
#   'harvard',
#   'the',
#   'the',
#   'having',
#   'having',
#   'the',
#   'this',
#   'pedestrians',
#   'their',
#   'a',
#   'that’s',
#   'holding',
#   'bacteria',
#   'harvard'],
#  'third': ['world', 'grade', 'world'],
#  'world': ['country', '♪', 'with', 'country'],
#  'country': ['and', 'and', 'and'],
#  'she': ['taught',
#   'refused',
#   'don’t',
#   'was',
#   'wrote',
#   'knows',
#   'is',
#   'doesn’t',
#   'was',
#   'said'],
#  'taught': ['me'],
#  'never': ['throw', 'know', 'know', 'finish', 'finish', 'called', 'go'],
#  'throw': ['away', 'up', 'up'],
#  'anything': ['because', 'about', 'so', 'look'],
#  'dictator’s': ['gonna'],
#  'overtake': ['the'],
#  'snatch': ['all'],
#  'wealth': ['so'],
#  'better': ['hold', 'looking', 'just'],
#  'hold': ['onto', 'onto'],
#  'onto': ['that', 'the', 'his'],
#  'retainer': ['from'],
#  'grade': ['’cause', 'it'],
#  'might': ['come', 'need', 'mean'],
#  'handy': ['as'],
#  'as': ['a',
#   'a',
#   'an',
#   'women',
#   'much',
#   'they',
#   'a',
#   'many',
#   'possible',
#   'the',
#   'freaky',
#   'me',
#   'a',
#   'old',
#   'her',
#   'wet',
#   'it',
#   'pentup',
#   'angry',
#   'possible',
#   'leverage',
#   'it'],
#  'shovel': ['when'],
#  'busy': ['stuffing', 'in', 'so', 'makin’'],
#  'stuffing': ['gold'],
#  'gold': ['up'],
#  'butt': ['and', 'hole', 'with', 'hole', 'cheeks', 'all', 'hole'],
#  'running': ['away'],
#  'communiststhe': ['last'],
#  'last': ['time', 'forever', 'boyfriend', 'time', 'year', 'boyfriend', 'year'],
#  'time': ['i',
#   'and',
#   'he',
#   'shitting',
#   'and',
#   'i',
#   'that',
#   'so',
#   'i',
#   'all',
#   'you',
#   'you',
#   'and',
#   'it',
#   'like',
#   'and'],
#  'was': ['at',
#   'trying',
#   'like',
#   'so',
#   'this',
#   'like',
#   'like',
#   'like',
#   'like',
#   'like',
#   'that',
#   'attending',
#   'like',
#   'a',
#   'like',
#   'living',
#   'like',
#   'like',
#   'like',
#   'like',
#   'like',
#   'like',
#   'cuban',
#   'like',
#   'like',
#   'like',
#   'legit',
#   'gonna',
#   'ready',
#   'ripe',
#   'rotten',
#   'people',
#   'free',
#   'like',
#   'you',
#   'like',
#   'like',
#   '‘oh',
#   'like',
#   'very',
#   'like',
#   'magical',
#   'to',
#   'sliced',
#   'sliced',
#   'like',
#   'like',
#   'gonna',
#   'starting',
#   'just',
#   'so',
#   'in',
#   'ok',
#   'clearly',
#   'that',
#   'easter',
#   'like',
#   'so',
#   'about',
#   'like',
#   'like',
#   'like',
#   'like',
#   'like',
#   '',
#   'like',
#   'like',
#   ''],
#  'san': ['francisco', 'francisco'],
#  'francisco': ['i', 'when'],
#  'trying': ['to', 'to', 'to', 'to', 'to', 'to', 'to', 'to'],
#  'her': ['get',
#   'to',
#   'book',
#   'lululemon',
#   'butt”',
#   'there',
#   'it’s',
#   'nipples',
#   'pussy',
#   'white',
#   'mexican',
#   'and',
#   'i'],
#  'rid': ['of'],
#  'ever': ['do', 'actually', 'happened'],
#  'do': ['that',
#   'know…',
#   'fancy',
#   'yoga',
#   'ayahuasca',
#   'silent',
#   'shit',
#   'it',
#   'it',
#   'anything',
#   'it',
#   'anything”',
#   'you',
#   'write',
#   'that',
#   'whatever',
#   'you',
#   'that',
#   'all',
#   'anal',
#   'it',
#   'and',
#   'it',
#   'get',
#   'whatever',
#   'this',
#   'that',
#   'it',
#   'you',
#   'in',
#   'some',
#   'whatever',
#   'for',
#   'shit',
#   'mushrooms',
#   'a',
#   'it',
#   'you'],
#  'worst': ['experience', 'thing'],
#  'experience': ['of', 'some'],
#  'life': ['it', 'i', 'you', 'is', 'and', 'right'],
#  'emotional': ['we', 'about'],
#  'were': ['screaming',
#   'all',
#   'in',
#   'hipsters',
#   'getting',
#   'done',
#   'like',
#   'discouraging',
#   'like',
#   '',
#   'alarmingly',
#   'suppositories',
#   'trying',
#   'like',
#   'the'],
#  'screaming': ['and'],
#  'fighting': ['and'],
#  'yelling': ['and'],
#  'came': ['to', 'outta', 'out'],
#  'climax': ['when'],
#  'refused': ['to', 'to'],
#  'let': ['go', 'me', 'it', 'me', 'their'],
#  'texas': ['instruments'],
#  'instruments': ['…'],
#  '…': ['manual'],
#  'manual': ['the', 'she', 'and'],
#  'know…': ['where', 'that', 'freaked'],
#  'calculator': ['is', 'is', 'that'],
#  'those': ['of', 'brains', 'comments', 'green', 'old', 'doctor', 'crazy'],
#  'under': [''],
#  'probably': ['don’t', 'pinterested', 'one', 'looked'],
#  'bamboozled': ['my'],
#  'generation': ['we', 'you'],
#  'required': ['to'],
#  'buy': ['it'],
#  'eight': ['grade'],
# ...
#  'too': ['much',
#   'nice',
#   'him',
#   'we',
#   'but',
#   'old',
#   'late',
#   'stupid',
#   'they',
#   'funky'],
#  'what’s': ['wrong', 'gonna', 'wrong'],
#  'wrong': ['with', 'with'],
#  'being': ['with', 'the', 'courageous'],
#  'feel': ['very…',
#   'very',
#   'like',
#   'more',
#   'like',
#   'like',
#   'rushed',
#   'like',
#   'so',
#   'bad'],
#  'very…': ['you'],
#  'picturesque': ['when'],
#  'wes': ['anderson'],
#  'anderson': ['movie'],
#  'movie': ['or', 'ok'],
#  'teach': ['you'],
#  'cool': ['stuff', 'stuff'],
#  'stuff': ['like', 'like'],
#  'voting': ['and'],
#  'recycling': ['and'],
#  'disturbing': ['documentaries'],
#  'documentaries': ['they'],
#  'introduce': ['you'],
#  'hot': ['hookin’', 'you', 'you'],
#  'hookin’': ['up'],
#  'mean': ['nothing', 'we’re', 'that', 'pay'],
#  'nothing': ['makes', 'they', 'for'],
#  'makes': ['me', 'me', 'sense'],
#  'more': ['powerful',
#   'like',
#   'options',
#   'doo',
#   'money',
#   'successful',
#   'to',
#   'women',
#   'handsome'],
#  'powerful': ['than'],
#  'eats': ['my'],
#  'pussy': ['oh', 'needs', 'is', 'was', 'to'],
#  'oh': ['my', 'my', 'you', 'my', 'my', 'my', 'maybe'],
#  'absorbing': ['all'],
#  'privilege': ['and'],
#  'entitlement…': ['…you'],
#  '…you': ['know'],
#  'through': ['the', 'southeast', 'and', 'a', 'it', 'a'],
#  'money': ['hole', 'they', 'you', 'if', 'you”', 'paid'],
#  'hole': ['and', 'it’s', 'feels', 'and'],
#  'just…': ['and', 'let’s', '“i', 'and'],
#  'vulnerable': ['down'],
#  'down': ['there',
#   'it’s',
#   'i',
#   'i',
#   'there',
#   'your',
#   'immediately',
#   'in',
#   'so',
#   'people',
#   'with'],
#  'crush': ['your', 'those', 'while'],
#  'head': ['at', 'first', 'shredding', 'and', 'for'],
#  'moment': ['white', 'to', 'you'],
#  'kill': ['you', 'me'],
#  'brains': ['colonize'],
#  'colonize': ['the'],
#  'colonizer”': ['you'],
#  'knowbut': ['i'],
#  'think': ['that',
#   'my',
#   'feminism',
#   'we',
#   'it’s',
#   'of',
#   'about',
#   'that’s',
#   'so',
#   'i’m'],
#  'marriage': ['it', 'i', 'because'],
#  'nice': ['to', 'we'],
#  'somebody': ['of', 'closes', 'closes'],
#  'own': ['race', 'goddamn'],
#  'race': ['the'],
#  'advantage': ['is'],
#  'home…': ['and'],
#  'racist': ['together'],
#  'say': ['whatever', 'to', '“you', '“you', 'be'],
#  'whatever': ['you', 'and', 'they', 'you', 'the'],
#  'explain': ['shit'],
#  'halffilipino': ['halfjapanese', 'and'],
#  'halfjapanese': ['i’m', 'and'],
#  'halfchinese': ['and', 'and'],
#  'halfvietnamese': ['and', 'so'],
#  'spend': [''],
#  'percent': ['of', 'of', 'spoken'],
#  'our': ['time',
#   'first',
#   'buddha',
#   'careers',
#   'job',
#   'day',
#   'society',
#   'first'],
#  'shitting': ['on'],
#  'korean': ['people'],
#  'amazing': ['it’s'],
#  'love': ['is', 'to', 'it', 'my', 'it', 'of'],
#  'built': ['on'],
#  'knowmy': ['last'],
#  'boyfriend': ['was', 'because'],
#  'cuban': ['and'],
#  'would': ['shit',
#   'double',
#   'not',
#   'have',
#   'i',
#   'crash”',
#   'simultaneously',
#   'explode',
#   'be',
#   'be',
#   'inevitably',
#   'only',
#   'be',
#   'come',
#   'just',
#   'close',
#   'jump',
#   'just',
#   'turn',
#   'just',
#   'talk'],
#  'mexican': ['people', 'friends'],
#  '“hold': ['it'],
#  'guys': ['aren’t', 'know', 'about', 'need', 'had”', 'can', 'doin’'],
#  'aren’t': ['mexican”'],
#  'mexican”': ['asianamerican'],
#  'underrated': ['i'],
#  'why': ['people', 'else', 'you', 'are', 'don’t', 'we’re', 'i’m', 'else'],
#  'sexiest': ['asian', 'they'],
#  'hair': ['from'],
#  'neck': ['down', 'and'],
#  'making': ['love'],
#  'dolphin': ['oh'],
#  'smooth': ['just'],
#  'slip': ['and'],
#  'slide': ['just'],
#  'black': ['fish', 'friends', 'friends'],
#  'fish': ['tilikum'],
#  'tilikum': ['all'],
#  'bed': ['every', 'women'],
#  'every': ['night',
#   'day”',
#   'single',
#   'day',
#   'day',
#   'day…',
#   'day',
#   'time',
#   'single',
#   'time'],
#  'oohwee': ['you'],
#  'mess': ['with', 'there’s'],
#  'jewish': ['dude', 'male'],
#  'afterwards': ['it’s', 'the', 'and', 'and', 'i'],
#  'red': ['and', 'light'],
#  'inflamed': ['and'],
#  'ask': ['to', 'for'],
#  'exfoliated': ['today”'],
#  'today”': ['“this'],
#  '“this': ['is'],
#  'jdate': ['more'],
#  'loofah': ['date'],
#  'thanks': ['for'],
#  'rug': ['burn'],
#  'burn': ['avi”', 'out'],
#  'avi”': ['and'],
#  'odor': ['none'],
#  'none': ['they', 'of'],
#  'smell': ['like', 'my', 'my', 'my', 'my', 'my'],
#  'responsibility': ['that’s'],
#  'umami': ['flavor'],
#  'flavor': ['comes'],
#  'comes': ['fromi', 'out', 'out', 'out', 'to'],
#  'fromi': ['think'],
#  'unspoken': ['understanding'],
#  'understanding': ['uh'],
#  'between': ['each', 'your'],
#  'each': ['other', 'other'],
#  'we’re': ['both',
#   'like',
#   'too',
#   'expected',
#   'so',
#   'such',
#   'trying',
#   'like',
#   'hippies'],
#  'both': ['halffancy', 'total', 'are'],
#  'halffancy': ['asian…'],
#  'asian…': ['…and'],
#  'halfjungle': ['asian'],
#  'difference': ['the'],
#  'fancy': ['asians', 'things'],
#  'asians': ['are', 'host', 'we'],
#  'chinese': ['the', 'scrolls', 'ladies', 'ladies'],
#  'japanese': ['they'],
#  'host': ['olympics', 'diseases'],
#  'olympics': ['jungle'],
#  'jungle': ['asians'],
#  'diseases': ['it’s…'],
#  'different': ['but', 'person', 'holes', 'people', 'it’s'],
#  'east': ['coast'],
#  'coast': ['going'],
#  'going': ['to', 'to', 'back', 'through', 'through', 'to'],
#  'private': ['school', 'school', 'school'],
#  'playing': ['lacrosse', 'chess', 'dumb', 'candy'],
#  'lacrosse': ['uh'],
#  'learning': ['latin'],
#  'latin': ['and'],
#  'chess': ['and'],
#  'rugby': ['he'],
#  'filipino': ['carlton'],
#  'carlton': ['ok'],
#  'didn’t': ['know', 'think', 'know', 'know'],
#  'vietnamese': ['people', 'i'],
#  'dates': ['he'],
#  'took': ['me', 'it', 'me'],
#  'restaurant': ['on', 'deaf'],
#  'west': ['side'],
#  'side': ['of', 'from', 'effect'],
#  'los': ['angeles'],
#  'angeles': ['called'],
#  'called': ['pho', 'lean', 'bossy'],
#  'pho': ['show'],
#  'show': ['he', 'off', 'i', 'him', 'signs', 'there’s'],
#  '“it’s': ['authentic', 'not'],
#  'authentic': ['vietnamese', 'ok”'],
#  'read': ['about'],
#  'yelp”': ['i'],
#  'ok”': ['you', '‘cause', 'and', 'and'],
#  'name': ['’cause'],
#  'number': ['in'],
#  'second': ['of', 'chance'],
#  'bathroom': ['if', 'would'],
#  'legit': ['the'],
#  'double': ['as', 'standard'],
#  'supply': ['closet'],
#  'closet': ['when'],
#  'gallons': ['of'],
#  'bleach': ['an'],
#  'atm': ['machine'],
#  'machine': ['and'],
#  'grandma': ['with'],
#  'glaucoma': ['napping'],
#  'napping': ['in'],
#  'corner': ['and'],
#  'wait': ['staff', 'to'],
#  'staff': ['here', 'and'],
#  'leave': ['this', 'without', 'you'],
#  'deaf': ['and'],
#  'emotionally': ['abused'],
#  'abused': ['i', 'the'],
#  'total': ['like'],
#  'big': ['hippies', 'fantasy', 'impact', 'like'],
#  'hippies': ['too', 'i’d'],
#  'backpack': ['through'],
#  'southeast': ['asia'],
#  'asia': ['we'],
#  'yoga': ['we'],
#  'ayahuasca': ['ceremonies'],
#  'ceremonies': ['we'],
#  'silent': ['meditation'],
#  'retreats': ['that’s'],
#  'pay': ['', 'for'],
#  'shut': ['up', 'up”', 'the'],
#  'weekend': ['we'],
#  'glutenfree': ['which'],
#  'means': ['we', 'i', 'the', 'ok', 'you’re'],
#  'bread': ['that', 'that’s', 'that’s'],
#  'tastes': ['like', 'when'],
#  'freerange': ['chewbacca'],
#  'chewbacca': ['we'],
#  'lesbian': ['bread'],
#  'like…': ['…a'],
#  '…a': ['thousand'],
#  'thousand': ['percent'],
#  'daily': ['fiber…', 'basis', 'basis…'],
#  'fiber…': ['and'],
#  'spoken': ['word'],
#  'word': ['poetry', '“bossy”', '“bossy”'],
#  'poetry': ['when'],
#  'queef': ['a'],
#  'shitty': ['poem', 'dads', 'mom'],
#  'poem': ['about…'],
#  'about…': ['…supporting'],
#  '…supporting': ['caitlyn'],
#  'caitlyn': ['jenner'],
#  'jenner': ['or'],
#  'funny': ['right', 'man'],
#  'sometimes': ['all'],
#  'hippydippy': ['shit'],
#  'do…': ['makes'],
#  'doing': ['an', 'anything', 'jack', 'it'],
#  'impression': ['of'],
#  'scrolls': ['up'],
#  'wall…': ['and'],
#  'neither': ['of'],
#  'us': ['know', 'and', 'to'],
#  'seems': ['to', 'to'],
#  'well': ['with', 'i', 'asian'],
#  'buddha': ['piggy'],
#  'piggy': ['bank'],
#  'bank': ['from'],
#  'pier': [''],
#  'imports': ['that'],
#  'providing': ['some'],
#  'some': ['good', 'risk', 'useful', 'lame', 'point', 'of'],
#  'good': ['feng', 'we', 'in', 'night'],
#  'feng': ['shui'],
#  'shui': ['for'],
#  'house': ['him', 'skin', '“hey'],
#  'four': ['years', 'days'],
#  'years': ['and', 'and', 'i’ve', 'old', 'old'],
#  'i–': ['i', 'i–', 'i', 'i'],
#  'sneaking': ['suspicion'],
#  'suspicion': ['that'],
#  'propose…': ['because…'],
#  'because…': ['i', 'they’re'],
#  'pressuring': ['him'],
#  'wacky': ['women’s'],
#  'intuition': ['that’s'],
#  'proposals': ['really'],
#  'work': ['ok',
#   'anymore',
#   'anymore',
#   'anymore',
#   'when',
#   'at',
#   'because',
#   'on',
#   'anymore',
#   'anymore',
#   'i',
#   'we'],
#  'incept': ['the'],
#  'idea': ['into'],
#  'man’s': ['head', 'eye'],
#  'passively': ['and'],
#  'doesn’t': ['get', 'see', 'have', 'have', 'believe'],
#  'message': ['extremely'],
#  'extremely': ['aggressively', 'itchy'],
#  'aggressively': ['you'],
#  'threaten': ['to'],
#  'without': ['ever'],
#  'actually': ['leaving'],
#  'leaving': ['because'],
#  'old': ['and', 'as', 'chinese', 'chinese', 'asian', 'and', 'when'],
#  'late': ['to'],
#  'new': ['man', 'world'],
#  'start': ['the', 'all', 'watching'],
#  'manipulation': ['cycle'],
#  'cycle': ['all'],
#  'again': ['so', 'and', 'it’s', 'but', 'because'],
#  '“i’m': ['just', 'gonna', 'just'],
#  'stick': ['with', 'your'],
#  'focus': ['on'],
#  'trapping': ['this'],
#  'nag': ['the'],
#  'outta': ['him', 'nowhere'],
#  'becomes': ['weak'],
#  'weak': ['and'],
#  'caves': ['in'],
#  'gets': ['fed', 'very'],
#  'fed': ['up'],
#  '“shut': ['the'],
#  'fine': ['will', 'by'],
#  'marry': ['me”', 'him'],
#  'me”': ['and', 'and'],
#  'always': ['like', 'very', 'feel', 'catch', 'means', 'tell', 'wanted'],
#  'proposed”': ['“it'],
#  '“it': ['came'],
#  'nowhere': ['and', 'and'],
#  'look': ['he', 'at', 'in', 'on', 'like', 'me', 'forward', 'like', 'like'],
#  'exact': ['ring'],
#  'ring': ['i'],
#  'wanted': ['how', 'to…', 'him', 'i’m'],
#  'maybe': ['he', 'you’ll', 'because'],
#  'pinterest': ['page', 'page…'],
#  'page': ['or'],
#  'something…': ['that'],
#  'sent': ['to'],
#  'best': ['friend', 'you'],
#  'friend': ['that'],
#  'send': ['to'],
#  'day”': ['let'],
#  'page…': ['he’s'],
#  'pinterested': ['in'],
#  'engaged': ['on'],
#  'saturday': ['i'],
#  'bought': ['my', 'me', 'our'],
#  'dress': ['the'],
#  'following': ['tuesday…'],
#  'tuesday…': ['because'],
#  'tried': ['it', 'to', 'to'],
#  'ready': ['i'],
#  'ripe': ['i'],
#  'rotten': ['i', 'i'],
#  'banana': ['bread'],
#  'surprised': ['at'],
#  'offstage': ['with'],
#  'completely': ['different'],
#  'you–': ['like', 'that'],
#  'recognize': ['my', 'your'],
#  'personality': ['at'],
#  'soft': ['and', 'serve'],
#  'nurturing': ['and'],
#  'domestic': ['we’ve'],
#  'we’ve': ['been'],
#  'i’ve': ['packed', 'been', 'been', 'asked', 'picked', 'been'],
#  'packed': ['his'],
#  'lunch': ['every'],
#  'single': ['day', 'night'],
#  'he’d': ['become'],
#  'become': ['dependent', 'the', 'a', 'this', 'some'],
#  'dependent': ['on'],
#  'graduated': ['from', 'from'],
#  'feed': ['him'],
#  'goodness': ['of'],
#  'heart': ['i'],
#  'investment': ['in'],
#  'financial': ['future'],
#  'reading': ['that'],
#  'book': ['by', 'that', 'is'],
#  'sheryl': ['sandberg', 'sandberg'],
#  'sandberg': ['she’s', 'that'],
#  'she’s': ['the', 'retired”i', 'waiting', 'timing', 'busy', 'got', 'from'],
#  'coo': ['of'],
#  'facebook': ['and'],
#  'wrote': ['that', 'lean'],
#  'riled': ['up'],
#  'careers': ['talking'],
#  'talking': ['about', 'about', 'about'],
#  'should': ['challenge', 'not'],
#  'challenge': ['ourselves'],
#  'ourselves': ['to'],
#  'sit': ['at'],
#  'table': ['and', 'and'],
#  'rise': ['to'],
#  'top': ['and'],
#  'lean': ['in', 'in', 'in'],
#  'lie': ['down', 'the'],
#  'want': ['to',
#   'they',
#   'their–',
#   'to',
#   'my',
#   'noah',
#   'i',
#   'for',
#   'to',
#   'your'],
#  'feminism': ['is'],
#  'job': ['used', 'we', 'at', 'most'],
#  'used': ['to', 'to', 'it'],
#  'smart': ['thing'],
#  'continue': ['playing'],
#  'dumb': ['for', 'women'],
#  'century': ['and', 'more'],
#  '“we’re': ['dumb', 'not'],
#  'guess': ['we', 'who'],
#  'stay': ['at', 'that’s'],
#  'snacks': ['and'],
#  'watch': ['ellen”', 'property', 'when', 'the'],
#  'ellen”': ['“‘cause'],
#  '“‘cause': ['we’re'],
#  'stupid': ['to'],
#  'real': ['responsibility”', 'boss', 'miracle'],
#  'responsibility”': ['and'],
#  '“we': ['could'],
#  'anything”': ['“bitch'],
#  '“bitch': ['shut'],
#  'up”': ['“don’t', 'and'],
#  '“don’t': ['tell'],
#  'secret”': ['they'],
#  'ruined': ['it'],
#  'expected': ['to'],
#  'hear': ['the', 'my', 'that'],
#  'phrase': ['“doubleincome', '“black'],
#  '“doubleincome': ['household”'],
#  'household”': ['i'],
#  'upset': ['with'],
#  'comments': ['and'],
#  '“but': ['ali', 'what'],
#  'options': ['now”', 'when'],
#  'now”': ['oh'],
#  'free': ['unscheduled', 'to', 'activity'],
#  'unscheduled': ['unsupervised'],
#  'unsupervised': ['and'],
#  'most': ['importantly', 'strongheaded', 'in', 'likely', 'of', 'of', 'women'],
#  'importantly': ['sponsored'],
#  'sponsored': ['do'],
#  'shittier': ['food'],
#  'food': ['tastes'],
#  'earn': ['ita'],
#  'ita': ['lot'],
#  'walk': ['around'],
#  'they’ll': ['get', 'be', 'get', 'be'],
#  'judgmental': ['about'],
#  'housewives': ['that', 'they', 'get', 'they', 'are', 'they'],
#  'street': ['and'],
#  '“look': ['at'],
#  'housewife': ['not', 'just', 'she’s', 'financially'],
#  'walking': ['around', 'like'],
#  'massages': ['in'],
#  'lululemon': ['pants”'],
#  'pants”': ['i’m'],
#  '“that': ['bitch'],
#  'bitch': ['is', 'had'],
#  'genius”': ['“she’s'],
#  '“she’s': ['not'],
#  'retired”i': ['do'],
#  'write': ['for'],
#  'fresh': ['off', 'off'],
#  'boat': ['on', 'i'],
#  'abc': ['yeah'],
#  'is…': ['it’s'],
#  'great': ['show', 'writing', 'dad'],
#  'coworkers': ['it’s', 'blow', 'blow', 'and'],
#  'writing': ['staff', 'job'],
#  'terms': ['of'],
#  'jobs': ['it’s'],
#  'still': ['gotta', 'here'],
#  'office': ['every', 'every', 'housewives', 'toilet'],
#  'skin': ['to', 'every'],
#  'seat': ['they'],
#  'use': ['that', 'that', 'the'],
#  'toilet': ['paper',
#   'paper',
#   'paper',
#   'paper',
#   'paper',
#   'and',
#   'i',
#   'the',
#   'and'],
#  'paper': ['cover', 'that', 'that', 'that’s', 'two'],
#  'cover': ['they'],
#  'gotta…': ['…ten'],
#  '…ten': ['times'],
#  'times': ['a'],
#  'day…': ['like'],
#  'sadass': ['meal'],
#  'meal': ['they'],
#  'oneply': ['toilet'],
#  'purposely': ['make'],
#  'difficult': ['to'],
#  'pull': ['out'],
#  'try': ['to', 'to', 'to', 'to', 'to'],
#  'ration': ['me'],
#  'communist': ['toilet'],
#  'effective': ['it'],
#  'dehydrates': ['your'],
#  'wiping': ['your', 'at', 'and'],
#  'desert': ['i'],
#  'literally': ['spat', 'trying'],
#  'spat': ['on'],
#  'days': ['ago', 'out', 'he', 'i'],
#  'ago': ['to'],
#  'macgyver': ['baby'],
#  'baby': ['wipe',
#   'they’ll',
#   'that',
#   'and',
#   'comes',
#   'hasn’t',
#   'can',
#   'can',
#   'from'],
#  'wipe': ['to'],
#  'moisten': ['it'],
#  'backfired': ['’cause'],
#  'fingers': ['broke',
#   'oh',
#   'afterwards',
#   'when',
#   'housewives',
#   'when',
#   'when',
#   'are',
#   'like'],
#  'broke': ['through', 'up'],
#  'digitally': ['stimulated'],
#  'stimulated': ['more'],
#  'doo': ['doo',
#   'to',
#   'doo',
#   'all',
#   'doo',
#   'comes',
#   'doo',
#   'comes',
#   'doo',
#   'on'],
#  'finish': ['wiping', 'wiping', 'i', 'it’s'],
#  'rushed': ['’cause'],
#  'paranoid': ['that'],
#  'coworker’s': ['gonna'],
#  'shoes': ['underneath', 'it’s'],
#  'underneath': ['the', 'the'],
#  'stall': ['and'],
#  'courtney’s': ['listening'],
#  'listening': ['she’s'],
#  'waiting': ['she’s', 'for'],
#  'timing': ['me”'],
#  'hurry': ['hurry', 'hurry', 'and', 'the'],
#  'feels': ['caked'],
#  'caked': ['in'],
#  'long': ['and', 'they'],
#  'dare': ['scratch', 'you'],
#  'scratch': ['yourself',
#   'on',
#   'myself',
#   'and',
#   'sniff',
#   '“what’s',
#   'yourself'],
#  'yourself': ['your', 'do', 'all'],
#  'underwear': ['at', 'and'],
#  'end': ['of'],
#  'looks': ['like'],
#  'goonies': ['housewives'],
#  'muffle': ['their'],
#  'worry': ['about', '’cause'],
#  'velocity': ['with'],
#  'squeeze': ['the'],
#  'cheeks': ['together'],
#  'sure': ['that', 'that', 'all'],
#  'slow': ['and'],
#  'steady': ['pace'],
#  'pace': ['so'],
#  'unpredictable': ['noise'],
#  'noise': ['suddenly'],
#  'suddenly': ['escapes'],
#  'escapes': ['and'],
#  'brings': ['you'],
#  'deep': ['deep', 'shame'],
#  'shame': ['housewives', 'your', 'they’re'],
#  'blow': ['ass', 'ass', 'ass', 'a'],
#  'echo': ['and'],
#  'reverberate': ['to'],
#  'ends': ['of'],
#  'hallways': ['while'],
#  'while': ['watching', 'it', 'i', 'i'],
#  'watching': ['as', 'porn', 'porn'],
#  'netflix': ['on'],
#  'ipad': ['as'],
#  'boring': ['repressed'],
#  'repressed': ['shits'],
#  'shits': ['they'],
#  'listen': ['to'],
#  'podcasts': ['planet'],
#  'planet': ['money'],
#  ...}

# %% [markdown]
# - here we want to keep the duplicates since that will tell us that this word has a higher probability to be spoken next

# %%
ali_dict.keys()
# Out:
# dict_keys(['ladies', 'and', 'gentlemen', 'please', 'welcome', 'to', 'the', 'stage', 'ali', 'wong', 'hi', 'hello', 'thank', 'you', 'for', 'coming', 'we', 'are', 'gonna', 'have', 'get', 'this', 'shit', 'over', 'with', '’cause', 'i', 'pee', 'in', 'like', 'ten', 'minutes', 'but', 'everybody', 'so', 'much', 'um…', 'it’s', 'a', 'very', 'exciting', 'day', 'me', 'been', 'year', 'turned', '', 'yes', 'five', 'people', 'appreciate', 'that', 'uh', 'can', 'tell', 'i’m', 'getting', 'older', 'because', 'now', 'when', 'see', 'an', 'girl', 'my', 'automatic', 'thought…', 'is', '“fuck', 'you”', 'don’t', 'even', 'know', 'fuck', '‘cause', 'straight', 'up', 'jealous', 'first', 'foremost', 'of', 'their', 'metabolism', 'girls', 'they', 'could', 'just', 'eat', 'then', 'take', 'sixpack', 'right', 'got', 'thatthat', 'beautiful', 'inner', 'thigh', 'clearance', 'where', 'put', 'feet', 'together', 'there’s', 'huge', 'gap', 'here', 'light', 'potential', 'radiating', 'throughand', 'go', 'sleep', 'insomnia', 'yet', 'what', 'ambien', 'or', 'download', 'meditation', 'oasis', 'podcast', 'calm', 'chatter', 'regret', 'resentment', 'towards', 'your', 'family', 'cluttering', 'mind', 'whole', 'lives', 'ahead', 'them', 'hpv', 'peace', 'at', 'night', 'has', 'ok', 'it', 'come', 'out', 'already', 'if', 'you’re', 'fucking', 'loser', 'all', 'that’s', 'says', 'about', 'lot', 'men', 'undetectable', 'really', 'fucked', 'ghost', 'inside', 'men’s', 'bodies', '“boo”', 'women’s', 'doctor', 'told', 'one', 'two', 'strains', 'either', 'kind', 'turn', 'into', 'cervical', 'cancer…', '…or', 'body', 'will', 'heal', 'itself', 'helpful', 'basically', 'die…', 'presence', 'wolverine', 'bitches', 'we’ll', 'find', 'um', 'also', 'kindle', 'turning', 'selfhelp', 'library', 'not', 'interested', 'books', 'fifty', 'shades', 'grey', 'lifechanging', 'magic', 'tidying', 'how', 'declutter', 'home', 'achieve', 'optimum', 'level', 'success', 'around', 'horrible', 'person', 'happy', 'am', 'help', 'tony', 'robbins', 'mei', 'hoarding', 'problem', 'which', 'hoping', 'center', 'other', 'problems', 'goes', 'away', 'disappear', 'mom', 'from', 'third', 'world', 'country', 'she', 'taught', 'never', 'throw', 'anything', 'dictator’s', 'overtake', 'snatch', 'wealth', 'better', 'hold', 'onto', 'retainer', 'grade', 'might', 'handy', 'as', 'shovel', 'busy', 'stuffing', 'gold', 'butt', 'running', 'communiststhe', 'last', 'time', 'was', 'san', 'francisco', 'trying', 'her', 'rid', 'ever', 'do', 'worst', 'experience', 'life', 'emotional', 'were', 'screaming', 'fighting', 'yelling', 'came', 'climax', 'refused', 'let', 'texas', 'instruments', '…', 'manual', 'know…', 'calculator', 'those', 'under', 'probably', 'bamboozled', 'generation', 'required', 'buy', 'eight', 'cost', 'thought', 'judy', 'jetson’s', 'laptop', 'future', 'graph', 'tesla', '“you', 'need', 'this”', '“but…', 'clean', 'die”', '“and', 'be', 'procrastinator', 'anymore', 'according', 'deepakoprah', 'way', 'success”', 'grew', 'past', 'married', 'yeah', 'man', 'who', 'lucky', 'guy', 'he', 'gave', 'something', 'him', 'forever', 'no', 'before', 'dated', 'losers', 'lots', 'skaters', 'wanna', 'grownass', 'woman', 'stop', 'dating', 'unless', 'wake', 'on', 'mattress', 'kitchen', 'they’re', 'sexy', 'outside', 'malt', 'liquor', 'husband', 'met', 'wedding', 'he’s–', 'he’s', 'looking', 'than', 'league', 'saw', '“oh', 'god', 'that”', 'thing', 'learned', 'attending', 'harvard', 'business', 'school', 'trap', 'his', 'ass”', '“going', 'trapped', 'ass', 'initially', 'by', 'kissing', 'until', 'fifth', 'date', 'unusual', 'move', 'part', 'did', 'purpose', 'knew', 'catch', '“all', 'gotta', 'make', 'dude', 'believe', 'secret', 'garden”', 'public', 'park…', '…that', 'hosted', 'many', 'reggae', 'fests…', '…and', 'accidentally', 'let…', 'homeless', 'hipsters', 'store', 'urban', 'outfitters', 'made', 'things', 'confusing…', 'hipster', 'beard', 'fashion', 'warmth', 'happened', 'to…', 'living', 'there', 'broad', 'daylight', 'had', 'had…', 'chemistry', '“hey', 'wassup”', '“wassup”', 'we–', 'n ...

# %%
ali_dict.values()
# Out:
# dict_values([['and', 'go', 'who', 'they', 'and', 'who'], ['gentlemen', 'foremost', 'then', 'have', 'there’s', 'resentment', 'get', 'get', 'says', 'my', 'she', 'snatch', 'running', 'fighting', 'yelling', 'it', 'everybody', 'my', 'she', 'i', 'uh', 'i', 'i', 'the', 'i', 'i', 'i', 'we', 'we–', 'then', 'i', 'watched', 'i', 'have', 'that', 'you', 'recycling', 'disturbing', 'it’s', 'all', 'just…', 'then', 'be', 'halfvietnamese', 'we', 'his', 'i', 'slide', 'your', 'inflamed', 'you’re', 'then', 'i', 'halfjapanese', 'i’m', 'halfvietnamese', 'playing', 'rugby', 'on', 'foremost', 'a', 'the', 'emotionally', 'i', '', 'so', 'neither', 'i', 'i–', 'then', 'it’s', 'find', 'start', 'just', 'caves', 'gets', 'is', 'then', 'look', 'like', 'very', 'for', 'i', 'she', 'rise', 'her', 'be', 'eat', 'watch', 'then', 'be', 'now', 'they’re', 'most', 'they’ll', 'in', 'then', 'digitally', 'then', 'you', 'you’re', 'then', 'then', 'then', 'then', 'steady', 'brings', 'let', 'reverberate', 'say', 'my', 'he', 'when', 'i’m', 'just', 'i', 'what', 'sicker', 'sicker', 'sicker', 'sicker', 'posted', 'they’re', 'that’s', 'lies', 'as', 'treat', 'you’ll', 'succeed', 'they', 'i', 'you', 'it’s', 'then', 'that’s', 'be', 'i’m', 'i', 'just', 'sisters', 'a', 'unusual', 'they’ll', 'boring”', 'all', 'their', 'wearing', 'famous', 'they', 'you’re', 'just', 'therefore', 'you', 'ignore', 'then', 'she', 'when', 'the', 'biggie', 'it–', 'it', 'your', 'there', 'i', 'a', 'i', 'push', 'then', 'then', 'melt', 'i', 'then', 'then', 'sniff', 'i', 'you’ve', 'i', 'outside', 'as', 'rapey', 'they', 'um…', 'most', 'see', 'i’d', 'i', 'he', 'instead', 'then', 'then', 'remember', 'then', 'hold', 'i', 'do', 'then', 'to', 'a', 'a', 'terrible', 'i', 'when', 'everything', 'the', 'i', 'then', 'i', 'most', 'i', 'he', 'i', 'held', 'got', 'i', 'your', 'just', 'he', 'i', 'it', 'leaves', 'dark', 'then', 'naked', 'a', 'i', 'i', 'my', 'then', 'then', 'recently', 'uh', 'me', 'now', 'a'], ['please'], ['welcome', 'no', 'look'], ['to', 'thank'], ['the', 'get', 'pee', 'sleep', 'sleep', 'have', 'take', 'calm', 'sleep', 'declutter', 'achieve', 'help', 'a', 'let', 'buy', 'clean', 'be', 'deepakoprah', 'achieve', 'a', 'trap', 'date', 'any', 'cool', 'be', 'go', 'say', 'a', 'be', 'do', 'private', 'this', 'see', 'leave', 'private', 'backpack', 'do', 'shut', 'go', 'be', 'do', 'incept', 'leave', 'go', 'my', 'send', 'him', 'be', 'sit', 'the', 'lie', 'women', 'be', 'continue', 'do', 'have', 'show', 'work', 'earn', 'shit', 'seat', 'eat', 'pull', 'ration', 'try', 'make', 'moisten', 'come', 'start', 'you', 'make', 'just', 'the', 'podcasts', 'me', 'come', 'me', 'get', 'work', 'eat', 'tell', 'get', 'you', 'make', 'fuck', 'marry', 'turn', 'youi', 'put', 'do', 'because', 'help', 'show', 'spank', 'abuse', 'be', 'be', 'do', 'her', 'use', 'say', 'like', 'get', 'like', 'the', 'take', 'see', 'think', 'heal', 'me', 'me', 'live', 'die', 'hide', 'alert', 'have', 'keep', 'go', 'be', 'support', 'be', 'the', 'protect', 'see', 'have', 'show', 'be', 'get', 'get', 'take', 'act', 'find', 'discretely', 'immediately', 'be', 'smell', 'protect', 'see', 'have', 'get', 'save', 'be', 'close', 'shut', 'see', 'finish', 'finish', 'come', 'make', 'be', 'be…', 'be', 'me', 'do', 'do', 'see', 'hire', 'keyser', 'freak', 'freak', 'it”', 'cleanse', 'assist', 'make', 'do', 'be', 'be', 'all', 'all', 'go', 'those', 'see', 'chip', 'keep', 'get', 'protect', 'trap', 'propose', 'me', 'harvard'], ['stage', 'light', 'chatter', 'kind', 'kind', 'presence', 'lifechanging', 'center', 'hoarding', 'hpv', 'country', 'third', 'communiststhe', 'worst', 'manual', 'calculator', 'future', 'tesla', 'manual', 'way', 'lucky', 'outside', 'inside', 'first', 'time', 'fifth', 'next', 'back', 'park”', 'middle', 'money', 'colonizer”', 'advantage', 'time', 'sexiest', 'sexiest', 'neck', 'last', 'rug', 'umami', 'difference', 'fancy', 'chinese', 'japanese', 'east', 'west', 'name', 'bathroom', 'bathroom', 'corner', 'wait', 'wall…', 'fuck', 'house', 'idea', 'man’s', 'message', 'whole', 'shit', 'fuck', 'w ...

# %% [markdown]
# # Create Text Generator
# Here we will program a text generation function that will take the following parameters.
# - The dictionary
# - Number of words you wish to be generated

# %%
# UDF for text generation
import random

# Input a dictionary in the format of key = current word, value = list of next words 
# along with the number of words you would like to see in your generated sentence
def generate_sentence(chain, count=15):
    # capitalize first word
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()
    
    # generate the second word from the value list
    # Set the new word as the first word
    # Repeat
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += " " + word2
        
    # end with a period
    sentence += '.'
    return sentence

# %%
generate_sentence(ali_dict)
# Out:
# 'Looking than me and you know because being courageous for coming true and halfvietnamese so.'
